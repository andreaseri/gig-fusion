# %% [markdown]
# # Underdog Recordstore Events Parser
# This notebook fetches events from [underdogrecordstore.de/vorverkauf](https://underdogrecordstore.de/vorverkauf)
# and enriches them with Spotify genre + artist link.

# %%
# !pip install requests beautifulsoup4 spotipy
# Out:
# Requirement already satisfied: requests in /Users/andreaseri/miniconda3/envs/eventing/lib/python3.11/site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in /Users/andreaseri/miniconda3/envs/eventing/lib/python3.11/site-packages (4.13.5)
# Requirement already satisfied: spotipy in /Users/andreaseri/miniconda3/envs/eventing/lib/python3.11/site-packages (2.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/andreaseri/miniconda3/envs/eventing/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/andreaseri/miniconda3/envs/eventing/lib/python3.11/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/andreaseri/miniconda3/envs/eventing/lib/python3.11/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/andreaseri/miniconda3/envs/eventing/lib/python3.11/site-packages (from requests) (2025.8.3)
# Requirement already satisfied: soupsieve>1.2 in /Users/andreaseri/miniconda3/envs/eventing/lib/python3.11/site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/andreaseri/miniconda3/envs/eventing/lib/python3.11/site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: redis>=3.5.3 in /Users/andreaseri/miniconda3/envs/eventing/lib/python3.11/site-packages (from spotipy) (5.2.0)

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import re
import time
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import musicbrainzngs

# %%
# Spotify Setup
SPOTIFY_CLIENT_ID = "31a82b3bec19482c8b4f9f9e4730f1dd"
SPOTIFY_CLIENT_SECRET = "4b3a6c5798e8401c9d36784f57558847"

spotify = spotipy.Spotify(
    auth_manager=SpotifyClientCredentials(
        client_id=SPOTIFY_CLIENT_ID,
        client_secret=SPOTIFY_CLIENT_SECRET
    )
)

# %%
def get_spotify_info(artist_name):
    try:
        result = spotify.search(q=f"artist:{artist_name}", type="artist", limit=1)
        items = result.get("artists", {}).get("items", [])
        if not items:
            return None, None
        artist = items[0]
        genres = artist.get("genres", [])
        link = artist.get("external_urls", {}).get("spotify")
        return genres, link
    except Exception as e:
        print("Spotify error:", e)
        return None, None

# %%
# Setup
musicbrainzngs.set_useragent("UnderdogEventsParser", "1.0")

def get_musicbrainz_genre(artist_name):
    try:
        result = musicbrainzngs.search_artists(artist=artist_name, limit=1)
        if result['artist-list']:
            artist = result['artist-list'][0]
            # MusicBrainz has 'tag-list' or 'type'
            tags = [t['name'] for t in artist.get('tag-list', [])]
            return tags
    except Exception as e:
        print("MusicBrainz error:", e)
    return None

# %%
from asyncio import events


URL = "https://underdogrecordstore.de/vorverkauf"

def fetch_events():
    resp = requests.get(URL)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    lines = [t.strip() for t in soup.stripped_strings]

    # Match date (dd.mm.), band, location, price
    event_pattern = re.compile(
        r"""
        ^\s*
        (?P<date>\d{2}\.\d{2}\.)                              # date: DD.MM.
        \s+
        (?P<band>.+?)                                         # band (lazy)
        (?=                                                   # band boundary lookahead
            (?:\s+@\s|                                        # next is '@ location'
            \s+[*]?(?:ab\s*)?\d+(?:[.,]\d{1,2})?\s*€?      # or price
            |\s*(?:$|\(|Ausverkauft|verlegt)               # or end/paren/status
            )
        )
        (?:\s+@\s*(?P<location>.+?)                           # optional @ location
            (?=(?:\s+[*]?(?:ab\s*)?\d+(?:[.,]\d{1,2})?\s*€?   # stop before price
            |\s*(?:$|\(|Ausverkauft|verlegt))              # or end/paren/status
            )
        )?
        (?:\s+[*]?(?P<price_prefix>ab\s*)?                    # optional * and 'ab '
            (?P<price>\d+(?:[.,]\d{1,2})?)\s*€?               # optional price
        )?
        (?:\s*(?P<status>Ausverkauft!?|verlegt[^\n]*))?       # optional status
        """,
        re.VERBOSE,
    )

    now = datetime.now()
    events = []
    section = ""
        
    for line in lines:
        m = event_pattern.search(line)
        if not m:
            section = line
            continue
        
        date, band, location, price, status = m.group("date", "band", "location", "price", "status")

        if line != "Underdog Shows:":
            location = section[:-1].strip()

        print(f"Parsing line: {band} on {date} at {location} for {price} EUR")

        # Add current year to date
        d = datetime.strptime(date + str(now.year), "%d.%m.%Y")

        # If the parsed date is in the past, assume next year
        if d.date() < now.date():
            d = d.replace(year=now.year + 1)

        # genres, link = get_spotify_info(band)
        # if not genres:
        #     genres = get_musicbrainz_genre(band)
        # time.sleep(0.1)

        band = band or ""
        location = location or ""

        genres, link = "", ""

        events.append({
            "date": d,
            "band": band.strip(),
            "location": location.strip(),
            "price_eur": "" if price is None else float(price.strip().replace(",", ".")),
            "genres": genres or "",
            "spotify_link": link or "",
            "status": status or "",
        })

    # ✅ Sort by true datetime
    # return sorted(events, key=lambda x: x["date"])
    return events


events = fetch_events()
# len(events)
# Out:
# Parsing line: Ritual on 02.10. at  for 37 EUR
# Parsing line: Duesenjaeger on 03.10. at  for 9 EUR
# Parsing line: Snake Eyes on 15.10. at  for 18 EUR
# Parsing line: Beach Bunny on 15.10. at  for 33,50 EUR
# Parsing line: ClickClickDecker on 18.10. at  for 27 EUR
# Parsing line: Grillmaster Flash on 23.10. at  for 20 EUR
# Parsing line: DYSE on 04.11. at  for 9 EUR
# Parsing line: Poison Ruin on 06.11. at  for 25 EUR
# Parsing line: Erik Cohen on 08.11. at  for 9 EUR
# Parsing line: Gorilla Biscuits, Terror, No Pressure on 17.11. at  for 41,50 EUR
# Parsing line: Saturdays at your place on 18.01. at  for 37 EUR
# Parsing line: A.A. Williams on 26.02. at  for 9 EUR
# Parsing line: Kafvka on 13.03. at  for 9 EUR
# Parsing line: Masters Of Reality on 02.10. at  for 38,45 EUR
# Parsing line: Bulgarian Cartrader on 07.10. at  for 28 EUR
# Parsing line: Power Plush on 10.10. at  for 28 EUR
# Parsing line: Sports Team on 12.10. at  for 28,15 EUR
# Parsing line: ClickClickDecker on 18.10. at  for 27 EUR
# Parsing line: Loki on 25.10. at  for 25,90 EUR
# Parsing line: Jonny Mahoro on 08.11. at  for 29,20 EUR
# Parsing line: Deki Alem on 12.11. at  for 26,40 EUR
# Parsing line: Paula Dalla Corte on 13.11. at  for 28,60 EUR
# Parsing line: Jamie Lawson on 14.11. at  for 30,45 EUR
# Parsing line: Romano on 13.03. at  for 40,65 EUR
# Parsing line: The Haunted Youth on 11.04. at  for 25,30 EUR
# Parsing line: Greg Freeman on 14.09. at  for 29,30 EUR
# Parsing line: Boyish on 22.09. at  for 24,70 EUR
# Parsing line: Preoccupations on 23.09. at  for 28,10 EUR
# Parsing line: Low Island on 27.10. at  for 29,20 EUR
# Parsing line: Jasmine.4.t on 02.11. at  for 30,45 EUR
# Parsing line: Deep Sea Diver on 03.11. at  for 28,15 EUR
# Parsing line: Shirley Holmes on 08.11. at  for 23,70 EUR
# Parsing line: The Roystone Club on 19.11. at  for 29,30 EUR
# Parsing line: The Pill on 10.12. at  for 24,70 EUR
# Parsing line: Pool Kids on 01.03. at  for 27 EUR
# Parsing line: Man/Woman/Chainsaw on 17.09. at  for 19,80 EUR
# Parsing line: Loving on 18.09. at  for 19,80 EUR
# Parsing line: Sababa on 23.09. at  for 5 EUR
# Parsing line: Ozan Ata Canani & Die Demokratie on 24.09. at  for 19,80 EUR
# Parsing line: TV Cult on 07.10. at  for 19,80 EUR
# Parsing line: Sophia Kennedy on 08.10. at  for 26,40 EUR
# Parsing line: False Lefty on 15.10. at  for 19,80 EUR
# Parsing line: Lawn Chair on 22.10. at  for 19,80 EUR
# Parsing line: U.S. Girls on 03.11. at  for 24,20 EUR
# Parsing line: Bachratten on 05.11. at  for 19,80 EUR
# Parsing line: The Wytches on 12.11. at  for 19,80 EUR
# Parsing line: Upchuck on 18.11. at  for 19,80 EUR
# Parsing line: Julian Knoth on 01.12. at  for 19,80 EUR
# Parsing line: Yuuf on 03.12. at  for 18,70 EUR
# Parsing line: The Hidden Cameras on 03.02. at  for 29,20 EUR
# Parsing line: Cory Hanson on 10.02. at  for 22 EUR
# Parsing line: Schramm on 11.02. at  for 25,90 EUR
# Parsing line: They Are Gutting A Body Of Water on 19.02. at  for 22 EUR
# Parsing line: Keshavara on 15.04. at  for 22 EUR
# Parsing line: Müllem Mon Amour on 20.09. at  for 46,20 EUR
# Parsing line: EivØr on 26.09. at  for 60,90 EUR
# Parsing line: Caamp on 19.10. at  for 44,35 EUR
# Parsing line: Ethel Cain on 21.10. at  for 44,50 EUR
# Parsing line: ZSK on 25.10. at  for 58,53 EUR
# Parsing line: The Kiffness on 30.10. at  for 43,50 EUR
# Parsing line: Hell Nights on 31.10. at  for 56,15 EUR
# Parsing line: Mac DeMarco on 04.11. at  for 49,45 EUR
# Parsing line: Stray From The Path on 08.11. at  for 44,40 EUR
# Parsing line: Fritz Kalkbrenner on 20.11. at  for 54,40 EUR
# Parsing line: Danko Jones on 11.12. at  for 40,05 EUR
# Parsing line: Dota on 17.12. at  for 41,20 EUR
# Parsing line: Lionheart on 23.01. at  for 49,49 EUR
# Parsing line: Syml on 08.02. at  for 40,05 EUR
# Parsing line: Wizo on 06.03. at  for 51,75 EUR
# Parsing line: Of Monsters and Men on 07.03. at  for 53,30 EUR
# Parsing line: Maximo Park on 08.03. at  for 49,10 EUR
# Parsing line: Betterov on 18.03. at  for 44,50 EUR
# Parsing line: Fatoni on 19.03. at  for 45,25 EUR
# Parsing line: Kanonenfieber on 20.03. at  for 44,70 EUR
# Parsing line: Kapelle Petra on 26.03. at  for 39,90 EUR
# Parsing line: Audio88 & Yassin on 19.06. at  for 43,75 EUR
# Parsing line: Those Damn Crows on 03.10. at  for 32,75 EUR
# Parsing line: Durand Bernarr on 14.10. at  for 29,30 EUR
# Parsing line: Monophonics on 26.10. at  for 29,20 EUR
# Parsing line: Chris James on 15.10. at  for 29,30 EUR
# Parsing line: McLusky on 13.11. at  for 27,50 EUR
# Parsing line: Obongjayar on 16.11. at  for 31,60 EUR
# Parsing line: John Maus on 19.11. at  for 29,20 EUR
# Parsing line: Chefket on 20.11. at  for 35,70 EUR
# Parsing line: Benjrose on 27.11. at  for 32,75 EUR
# Parsing line: Tristan Brusch on 11.03. at  for 32 EUR
# Parsing line: The Magic Mumble Jumble on 29.03. at  for 35,90 EUR
# Parsing line: Henge on 13.04. at  for 29,20 EUR
# Parsing line: Dari on 28.11. at  for 34,90 EUR
# Parsing line: Better Lovers on 26.09. at  for 32,75 EUR
# Parsing line: Jeffrey Lewis on 30.09. at  for 26,96 EUR
# Parsing line: The Vintage Caravan on 03.10. at  for 32,50 EUR
# Parsing line: The Obsessed on 15.10. at  for 29,20 EUR
# Parsing line: Castle Rat on 21.10. at  for 29,20 EUR
# Parsing line: Leftovers on 25.10. at  for 28,60 EUR
# Parsing line: Poison Ruin on 06.11. at  for 25 EUR
# Parsing line: The Summer Set on 07.11. at  for 31,60 EUR
# Parsing line: Kochkraft durch KMA on 08.11. at  for 28,35 EUR
# Parsing line: Booze & Glory on 14.11. at  for 34,70 EUR
# Parsing line: The Young Gods on 17.11. at  for 31,80 EUR
# Parsing line: Mother Tongue on 25.11. at  for 33,60 EUR
# Parsing line: Rise Of The Northstar on 09.12. at  for 44,50 EUR
# Parsing line: Deaf Havana on 29.01. at  for 31,60 EUR
# Parsing line: Schmutzki on 12.03. at  for 38,45 EUR
# Parsing line: We Came As Romans on 04.10. at  for 47,90 EUR
# Parsing line: Nasty on 11.10. at  for 37 EUR
# Parsing line: Jaill on 18.10. at  for 39,40 EUR
# Parsing line: Curtis Harding on 04.11. at  for 44,25 EUR
# Parsing line: Guilt Trip on 28.11. at  for 33,75 EUR
# Parsing line: Chelsea Grin on 30.11. at  for 43,35 EUR
# Parsing line: Of Mice And Men on 05.12. at  for 42,40 EUR
# Parsing line: HGich.T on 16.01. at  for 34,70 EUR
# Parsing line: Earl Sweatshirt on 08.02. at  for 46,40 EUR
# Parsing line: Mobb Deep on 16.04. at  for 44 EUR
# Parsing line: Oxo on 19.12. at  for 86 EUR
# Parsing line: Lord Huron on 15.09. at  for 43,50 EUR
# Parsing line: The Cat Empire on 06.10. at  for 49,25 EUR
# Parsing line: Larkin Poe on 26.10. at  for 55,75 EUR
# Parsing line: Skindred on 16.11. at  for 44,65 EUR
# Parsing line: Big Thief on 14.04. at  for 54,24 EUR
# Parsing line: Moneybrother on 13.09. at  for 38,20 EUR
# Parsing line: Richy Mitch & The Coal Miners on 14.09. at  for 32,75 EUR
# Parsing line: Ten56. on 18.09. at  for 31,60 EUR
# Parsing line: Poison The Well on 19.09. at  for 46,95 EUR
# Parsing line: Young Rebel Set on 20.09. at  for 37,20 EUR
# Parsing line: Darkest Hour on 26.09. at  for 40,85 EUR
# Parsing line: Malou Lovis on 29.09. at  for 29 EUR
# Parsing line: Shame on 30.09. at  for 35,90 EUR
# Parsing line: Zoot Woman on 02.10. at  for 35,90 EUR
# Parsing line: Duesenjaeger on 03.10. at  for 24,50 EUR
# Parsing line: Witch Club Satan on 05.10. at  for 26,96 EUR
# Parsing line: Sharktank on 07.10. at  for 34,90 EUR
# Parsing line: Sophia Kennedy on 08.10. at  for 26,40 EUR
# Parsing line: Starsailor on 10.10. at  for 34,70 EUR
# Parsing line: Inspector Cluzo on 11.10. at  for 30,45 EUR
# Parsing line: bac on 15.10. at  for 30 EUR
# Parsing line: L.A. Salami on 16.10. at  for 27,50 EUR
# Parsing line: As December Falls on 17.10. at  for 30,70 EUR
# Parsing line: Orannsi Pazuzu on 18.10. at  for 30,37 EUR
# Parsing line: Joya Marleen on 20.10. at  for 26 EUR
# Parsing line: Herrenmagazin on 23.10. at  for 27,70 EUR
# Parsing line: Drei Meter Feldweg on 24.10. at  for 30,20 EUR
# Parsing line: Augn on 25.10. at  for 28,10 EUR
# Parsing line: Alarmsignal on 01.11. at  for 30,95 EUR
# Parsing line: Hotel Rimini on 02.11. at  for 27,50 EUR
# Parsing line: Roya on 03.11. at  for 33,90 EUR
# Parsing line: DYSE on 04.11. at  for 29,50 EUR
# Parsing line: Easy Easy on 05.11. at  for 25,90 EUR
# Parsing line: Foxwarren on 06.11. at  for 30,45 EUR
# Parsing line: Pogendroblem on 07.11. at  for 24,20 EUR
# Parsing line: Erik Cohen on 08.11. at  for 28 EUR
# Parsing line: Ghostwoman on 10.11. at  for 27,50 EUR
# Parsing line: King Hannah on 11.11. at  for 29,20 EUR
# Parsing line: McLusky on 13.11. at  for 27,50 EUR
# Parsing line: Cate Le Bon on 14.11. at  for 29,70 EUR
# Parsing line: Balthvs on 15.11. at  for 37,20 EUR
# Parsing line: Mono on 17.11. at  for 34,70 EUR
# Parsing line: Minami Deutsch on 18.11. at  for 26,40 EUR
# Parsing line: Van Holzen on 20.11. at  for 29,10 EUR
# Parsing line: Marathonmann on 21.11. at  for 29,80 EUR
# Parsing line: Matt Anderson on 23.11. at  for 34,70 EUR
# Parsing line: Frankie And The Witchfingers on 25.11. at  for 25,30 EUR
# Parsing line: Friso on 01.12. at  for 33,70 EUR
# Parsing line: Lambrini Girls on 07.12. at  for None EUR
# Parsing line: The Meteors on 09.12. at  for 31,95 EUR
# Parsing line: Iedereen on 11.12. at  for 24,20 EUR
# Parsing line: Extrabreit on 12.12. at  for 44,85 EUR
# Parsing line: KMPFSPRT on 13.12. at  for 24,20 EUR
# Parsing line: Loathe on 14.12. at  for 37,30 EUR
# Parsing line: Bernd Begemann on 27.12. at  for 22 EUR
# Parsing line: Born Of Osiris on 09.01. at  for 42,95 EUR
# Parsing line: Demented Are Go on 10.01. at  for 32,95 EUR
# Parsing line: Pabst on 23.01. at  for 27,50 EUR
# Parsing line: Nanowar Of Steel on 29.01. at  for 40,70 EUR
# Parsing line: Kontrollverlust on 31.01. at  for 32,40 EUR
# Parsing line: Anna Von Hausswolff on 04.02. at  for 32,75 EUR
# Parsing line: Arms Lenght on 20.02. at  for 33,35 EUR
# Parsing line: Elwood Stray & Our Mirage on 21.02. at  for 28,95 EUR
# Parsing line: Rosmarin on 22.02. at  for 30,70 EUR
# Parsing line: A.A. Williams on 26.02. at  for 29 EUR
# Parsing line: Good Neighbours on 03.03. at  for 33,90 EUR
# Parsing line: Kafvka on 13.03. at  for 31,30 EUR
# Parsing line: Spidergawd on 17.03. at  for 41,50 EUR
# Parsing line: Kapa Tult on 18.03. at  for 27,50 EUR
# Parsing line: Doctor Krapula on 27.03. at  for 26,40 EUR
# Parsing line: Full Of Hell, The Body on 04.04. at  for 33,77 EUR
# Parsing line: Lansdowne on 16.04. at  for 29,10 EUR
# Parsing line: The Toten Crackhuren im Kofferraum on 17.04. at  for 33,50 EUR
# Parsing line: Hundreds on 21.04. at  for 42,75 EUR
# Parsing line: Salò on 07.05. at  for 33,80 EUR
# Parsing line: Hardline on 08.05. at  for 41,50 EUR
# Parsing line: Rami Hattab on 30.05. at  for 34,70 EUR
# Parsing line: Hooverphonic on 06.10. at  for 51,70 EUR
# Parsing line: Black Country, New Road on 14.10. at  for 35,20 EUR
# Parsing line: Beach Bunny on 15.10. at  for 33,50 EUR
# Parsing line: Die Höchste Eisenbahn on 01.12. at  for 42,20 EUR
# Parsing line: Erdmöbel on 22.12. at  for 35,10 EUR
# Parsing line: Yin Yin on 05.03. at  for 29,80 EUR
# Parsing line: Black Sea Dahu on 01.04. at  for 41,85 EUR
# Parsing line: Milliarden on 02.04. at  for 39,90 EUR
# Parsing line: Herrenmagazin on 10.12. at  for 41,05 EUR
# Parsing line: Caleb Hearn on 23.09. at  for 29,30 EUR
# Parsing line: Blondshell on 25.09. at  for 30,30 EUR
# Parsing line: Rachel Grae on 01.10. at  for 23,55 EUR
# Parsing line: Ritual on 02.10. at  for 22,50 EUR
# Parsing line: Hellsongs on 09.10. at  for 25,90 EUR
# Parsing line: Tim Vantol on 11.10. at  for 35,70 EUR
# Parsing line: Catapults on 16.10. at  for 23,70 EUR
# Parsing line: The Vices on 26.10. at  for 27,60 EUR
# Parsing line: Greyscale on 09.11. at  for 30,55 EUR
# Parsing line: Softcult on 18.11. at  for 25,85 EUR
# Parsing line: Swim School on 22.11. at  for 28,15 EUR
# Parsing line: Pudeldame on 25.11. at  for 28,10 EUR
# Parsing line: Sparkling on 28.11. at  for 22 EUR
# Parsing line: Slow Crush on 30.11. at  for 30,70 EUR
# Parsing line: Saturdays at your place on 18.01. at  for 25 EUR
# Parsing line: Still Talk on 24.01. at  for 25,90 EUR
# Parsing line: Eläkeläiset on 20.04. at  for 30,30 EUR
# Parsing line: Hohnen Ford on 05.10. at  for 29,15 EUR
# Parsing line: Ende on 15.10. at  for 23,70 EUR
# Parsing line: Afar on 24.10. at  for 22 EUR
# Parsing line: Ethan Regan on 07.12. at  for 28,15 EUR
# Parsing line: David Bay on 08.12. at  for 23,70 EUR
# Parsing line: Dope Lemon on 15.09. at  for 47,80 EUR
# Parsing line: Umse on 27.09. at  for 34,70 EUR
# Parsing line: Siena Root on 02.10. at  for 27 EUR
# Parsing line: The Beths on 03.10. at  for 27,50 EUR
# Parsing line: The Pharcyde on 16.10. at  for 55,10 EUR
# Parsing line: Anda Morts on 28.10. at  for 30,30 EUR
# Parsing line: Everything Everything on 03.11. at  for 36,20 EUR
# Parsing line: Gorilla Biscuits, Terror, No Pressure on 17.11. at  for 41,50 EUR
# Parsing line: Baxter Dury on 27.11. at  for 44,65 EUR
# Parsing line: Lambrini Girls on 07.12. at  for 27,50 EUR
# Parsing line: Slime on 23.01. at  for 44,90 EUR
# Parsing line: Tortoise on 27.01. at  for 42,40 EUR
# Parsing line: Blossoms on 10.02. at  for 33,90 EUR
# Parsing line: Sprints on 14.03. at  for 33,90 EUR
# Parsing line: Geese on 18.03. at  for 30,45 EUR
# Parsing line: Godspeed You! Black Emperor on 20.03. at  for 41,87 EUR
# Parsing line: She Past Away on 08.05. at  for 40,77 EUR
# Parsing line: Bonaparte on 29.10. at  for 47,25 EUR
# Parsing line: Betterov on 15.10. at  for 44,50 EUR
# Parsing line: Jadu Heart on 04.11. at  for 37,20 EUR
# Parsing line: Becky Sikasa on 07.11. at  for 27,50 EUR
# Parsing line: Steiner & Madlaina on 11.11. at  for 44,50 EUR
# Parsing line: Cara Rose on 13.11. at  for 29,20 EUR
# Parsing line: Fil Bo Riva on 19.11. at  for 47,25 EUR
# Parsing line: Fortuna Ehrenfeld on 09.12. at  for 44,63 EUR
# Parsing line: Fortuna Ehrenfeld on 10.12. at  for 44,63 EUR
# Parsing line: Bob Dylan on 03.11. at  for 70 EUR
# Parsing line: Nina Chuba on 06.11. at  for 52,90 EUR
# Parsing line: Gogol Bordello on 13.09. at  for 46,95 EUR
# Parsing line: Mogwai on 20.09. at  for 50,32 EUR
# Parsing line: Basement on 26.09. at  for 35,90 EUR
# Parsing line: The Midnight on 28.09. at  for 43,50 EUR
# Parsing line: Igorrr on 12.10. at  for 44,50 EUR
# Parsing line: Atreyu on 18.10. at  for 46,95 EUR
# Parsing line: Banks on 20.10. at  for 47 EUR
# Parsing line: Paradise Lost on 23.10. at  for 49,25 EUR
# Parsing line: Jonny Maar on 26.10. at  for 45,05 EUR
# Parsing line: Kadavar on 28.10. at  for 44,50 EUR
# Parsing line: The Darkness on 30.10. at  for 44,65 EUR
# Parsing line: Arrested Development on 02.11. at  for 55 EUR
# Parsing line: Kae Tempest on 03.11. at  for 49,28 EUR
# Parsing line: Malevolence on 05.11. at  for 47 EUR
# Parsing line: John Butler on 08.11. at  for 45 EUR
# Parsing line: Noga Erez on 23.11. at  for 45 EUR
# Parsing line: Joy Crookes on 29.11. at  for 41,80 EUR
# Parsing line: Clutch on 10.12. at  for 43,50 EUR
# Parsing line: Counterparts on 05.02. at  for 44,40 EUR
# Parsing line: White Lies on 24.02. at  for 46,95 EUR
# Parsing line: La Dispute on 10.03. at  for 35,05 EUR
# Parsing line: Prinz Pi on 11.10. at  for 52,79 EUR
# Parsing line: Nova Twins on 21.09. at  for 28,15 EUR
# Parsing line: Billie Marten on 02.11. at  for 30,45 EUR
# Parsing line: Flipturn on 04.11. at  for 30,45 EUR
# Parsing line: Destroyer + The Weather Station on 08.11. at  for 34,70 EUR
# Parsing line: Skinny Lister on 29.11. at  for 32,75 EUR
# Parsing line: Deaf Havana on 23.01. at  for 30,45 EUR
# Parsing line: Teenage Dads on 17.09. at  for 28,15 EUR
# Parsing line: L.A. Witch on 30.09. at  for 30,45 EUR
# Parsing line: Big Special on 28.10. at  for 32,60 EUR
# Parsing line: Triggerfinger on 12.11. at  for 32,50 EUR
# Parsing line: Sons on 22.11. at  for 27 EUR
# Parsing line: Florence Black on 26.11. at  for 30,60 EUR
# Parsing line: The Scratch on 27.11. at  for 30,45 EUR
# Parsing line: Deviloof on 02.12. at  for 47,65 EUR
# Parsing line: Militarie Gun on 30.01. at  for 30,45 EUR
# Parsing line: The Aces on 11.02. at  for 31,60 EUR
# Parsing line: Tulpe on 21.02. at  for 29,40 EUR
# Parsing line: Coach Party on 28.02. at  for 27 EUR
# Parsing line: Indie Cologne Fest on 21.09. at  for 17,60 EUR
# Parsing line: Little Simz on 29.09. at  for 56,75 EUR
# Parsing line: Meute on 02.10. at  for 59,35 EUR
# Parsing line: Loyle Carner on 22.10. at  for 68,25 EUR
# Parsing line: OG Keemo on 25.10. at  for 44,49 EUR
# Parsing line: Von Wegen Lisbeth on 01.11. at  for 48 EUR
# Parsing line: H-Blockx on 02.11. at  for 58,70 EUR
# Parsing line: Dropkick Murphys on 03.11. at  for 67,90 EUR
# Parsing line: Dropkick Murphys on 04.11. at  for 67,90 EUR
# Parsing line: Wolf Alice on 17.11. at  for 45,25 EUR
# Parsing line: Blond on 18.11. at  for 47,40 EUR
# Parsing line: Killwitch Engage on 20.11. at  for 59 EUR
# Parsing line: Mine on 25.11. at  for 61,90 EUR
# Parsing line: The Hives on 01.12. at  for 57,55 EUR
# Parsing line: Royal Otis on 08.12. at  for 47 EUR
# Parsing line: Landmvrks on 19.12. at  for 56,45 EUR
# Parsing line: Jinjer on 23.01. at  for 51,25 EUR
# Parsing line: Heaven Shall Burn on 28.02. at  for 69,40 EUR
# Parsing line: Franz Ferdinand on 04.04. at  for 62,50 EUR
# Parsing line: Kaffkiez on 12.04. at  for 54,40 EUR
# Parsing line: Sportfreunde Stiller on 11.05. at  for 53,85 EUR
# Parsing line: Fortuna Ehrenfeld on 22.10. at  for 28,50 EUR
# Parsing line: Fortuna Ehrenfeld on 23.10. at  for 28,50 EUR
# Parsing line: Toxoplasma on 12.09. at  for 16,50 EUR
# Parsing line: The Slapstickers on 13.09. at  for 17,60 EUR
# Parsing line: Lord Rochester on 16.09. at  for 16,50 EUR
# Parsing line: Popperklopper on 19.09. at  for 14,30 EUR
# Parsing line: The Vovos on 20.09. at  for 15,40 EUR
# Parsing line: Violencia on 24.09. at  for 14,30 EUR
# Parsing line: Guts Pie Earshot on 25.09. at  for 15,40 EUR
# Parsing line: Bratakus on 26.09. at  for 14,30 EUR
# Parsing line: The Tips on 02.10. at  for 15,40 EUR
# Parsing line: Hamburger Spinners on 04.10. at  for 16,50 EUR
# Parsing line: Negative Blast on 08.10. at  for 15,40 EUR
# Parsing line: Karaoke Till Death on 09.10. at  for 16,50 EUR
# Parsing line: Karaoke Till Death on 10.10. at  for 16,50 EUR
# Parsing line: The Backyard Band on 18.10. at  for 15,40 EUR
# Parsing line: The Quakes on 29.10. at  for 17,60 EUR
# Parsing line: Banana Peel Slippers on 01.11. at  for 16,50 EUR
# Parsing line: Bazooka Zirkus on 07.11. at  for 14,30 EUR
# Parsing line: The Turbo A.C.s on 13.11. at  for 16,50 EUR
# Parsing line: Der Dumme August on 14.11. at  for 14,30 EUR
# Parsing line: The Darts on 18.11. at  for 16,50 EUR
# Parsing line: Sedlmeir on 20.11. at  for 15,40 EUR
# Parsing line: Karoshi on 21.11. at  for 15,40 EUR
# Parsing line: The Schizophonics on 22.11. at  for 17,60 EUR
# Parsing line: Long Tall Texans on 26.11. at  for 16,50 EUR
# Parsing line: Nichts on 05.12. at  for 16,50 EUR
# Parsing line: Jesper Munk on 15.10. at  for 31,40 EUR
# Parsing line: The Rural Alberta Advantage on 10.12. at  for 35 EUR
# Parsing line: Grandbrothers on 01.11. at  for 41,60 EUR
# Parsing line: Erobique on 30.12. at  for 42,20 EUR
# Parsing line: Divine Comedy on 15.03. at  for 53,90 EUR
# Parsing line: Belle & Sebastian performing Tigermilk on 17.03. at  for 55 EUR
# Parsing line: Belle & Sebastian performing If You’re Feeling Sinister on 18.03. at  for 55 EUR
# Parsing line: JNSN on 27.09. at  for 21 EUR
# Parsing line: Sick Fizz on 09.10. at  for 17,88 EUR
# Parsing line: Snake Eyes on 15.10. at  for 18 EUR
# Parsing line: Grillmaster Flash on 23.10. at  for 20 EUR
# Parsing line: Drangsal on 27.09. at  for 41,75 EUR
# Parsing line: K’s Choice on 08.10. at  for 52,95 EUR
# Parsing line: Refused on 10.10. at  for 49,45 EUR
# Parsing line: Coheed And Cambria on 11.10. at  for 44,50 EUR
# Parsing line: Mantar on 24.10. at  for 34,70 EUR
# Parsing line: The Subways on 24.11. at  for 40,05 EUR
# Parsing line: Deus on 24.03. at  for 51 EUR
# Parsing line: Nickless on 29.10. at  for 29,10 EUR
# Parsing line: Neon Dreams on 12.11. at  for 25,90 EUR
# Parsing line: Donots on 19.09. at  for 52,75 EUR
# Parsing line: Antilopden Gang on 20.09. at  for 53,05 EUR
# Parsing line: Soap & Skin on 17.10. at  for 49,45 EUR
# Parsing line: RedHook on 10.05. at  for 25,80 EUR
# Parsing line: Bulgarian Cartrader on 07.10. at  for 28 EUR
# Parsing line: Mar Malade on 03.10. at  for 23,70 EUR
# Parsing line: Bertie Newman on 26.11. at  for 25,90 EUR
# Parsing line: Chloe Moriondo on 15.09. at  for 30,45 EUR
# Parsing line: Sofie Royer on 22.09. at  for 25,90 EUR
# Parsing line: Kings Elliot on 11.10. at  for 33,30 EUR
# Parsing line: Great Grandpa on 05.11. at  for 30,45 EUR
# Parsing line: Panic Shack on 22.11. at  for 30,30 EUR
# Parsing line: Jerub on 28.11. at  for 33,90 EUR
# Parsing line: Big Sleep on 02.12. at  for 28,15 EUR
# Parsing line: Noso on 10.02. at  for 24,70 EUR

# %%
URL = "https://underdogrecordstore.de/vorverkauf"

def fetch_locations():
    resp = requests.get(URL)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")
    lines = [t.strip() for t in soup.stripped_strings]
    return [line[:-1].strip() for line in lines if line.endswith(":")]

def fetch_events():
    locations = fetch_locations()
    # loc_pattern = r"|".join(re.escape(loc) for loc in locations)

    loc_pattern = r"|".join(
        re.escape(loc) for loc in sorted(locations, key=len, reverse=True)
    )

    print("loc_pattern:", loc_pattern)

    # Regex to parse a concert line
    event_pattern = re.compile(
        # r"""
        # ^\s*
        # (?P<date>\d{{2}}\.\d{{2}}\.)                              # date: DD.MM.
        # \s+
        # (?P<band>.+?)                                             # band (lazy)
        # (?=                                                       # band boundary lookahead
        #     (?:\s+@\s|                                            # '@ location'
        #        \s+[*]?(?:ab\s*)?\d+(?:[.,]\d{{1,2}})?\s*€?        # or price
        #      |\s*(?:$|\(|Ausverkauft|verlegt)                     # or end/paren/status
        #     )
        # )
        # (?:\s+@\s*(?P<location>(?:{loc_pattern}|.+?)))?           # optional @ location
        # (?:\s+[*]?(?P<price_prefix>ab\s*)?                        # optional * and 'ab '
        #     (?P<price>\d+(?:[.,]\d{{1,2}})?)\s*€?                 # optional price
        # )?
        # (?:\s*(?P<status>Ausverkauft!?|verlegt[^\n]*))?           # optional status
        
        
        
        # ^\s*
        # (?P<date>\d{2}\.\d{2}\.)                              # date: DD.MM.
        # \s+
        # (?P<band>.+?)                                         # band
        # (?=                                                   # band boundary lookahead
        #     (?:\s+@\s|                                        # '@ location'
        #        \s+[*]?(?:ab\s*)?\d+(?:[.,]\d{1,2})?\s*€?      # or price
        #      |\s*(?:$|\(|Ausverkauft|verlegt)                 # or end/paren/status
        #     )
        # )
        # (?:\s+@\s*(?P<location>(?:{loc_pattern}|.+?))
        #     (?=(?:\s+[*]?(?:ab\s*)?\d+(?:[.,]\d{1,2})?\s*€?   # stop before price
        #        |\s*(?:$|\(|Ausverkauft|verlegt))              # or end/paren/status
        #     )
        # )?       # optional @ location
        # # (?:\s+@\s*(?P<location>.+?)                           # optional @ location
        # #     (?=(?:\s+[*]?(?:ab\s*)?\d+(?:[.,]\d{1,2})?\s*€?   # stop before price
        # #        |\s*(?:$|\(|Ausverkauft|verlegt))              # or end/paren/status
        # #     )
        # # )?
        # (?:\s+[*]?(?P<price_prefix>ab\s*)?                    # optional 'ab' or '*'
        #     (?P<price>\d+(?:[.,]\d{1,2})?)\s*€?               # optional price
        # )?
        # (?:\s*(?P<status>Ausverkauft!?|verlegt[^\n]*))?       # optional status

        
        # ^\s*
        # (?P<date>\d{{2}}\.\d{{2}}\.)                              # Datum: DD.MM.
        # \s+
        # (?P<band>.+?)                                             # Band (lazy)
        # (?=                                                       # Band endet vor:
        #     (?:\s+@\s|                                            #   '@ location'
        #        \s+[*]?(?:ab\s*)?\d+(?:[.,]\d{{1,2}})?\s*€?        #   Preis
        #      |\s*(?:$|\(|Ausverkauft|verlegt)                     #   EOL/ Klammer / Status
        #     )
        # )
        # (?:\s+@\s*(?P<location>(?:{loc_pattern})))?               # optionale @ Location (nur bekannte)
        # (?:\s+[*]?(?P<price_prefix>ab\s*)?                        # optional '*' / 'ab'
        #     (?P<price>\d+(?:[.,]\d{{1,2}})?)\s*€?                 # optional Preis
        # )?
        # (?:\s*(?P<status>Ausverkauft!?|verlegt[^\n]*))?           # optionaler Status


        rf"""
        ^\s*
        (?P<date>\d{{2}}\.\d{{2}}\.)                   # date: DD.MM.
        \s+
        (?P<band>.+?)                                  # band (lazy)
        (?=                                            # band ends before:
            (?:\s+@\s|                                 #   '@ location'
               \s+[*]?(?:ab\s*)?\d+(?:[.,]\d{{1,2}})?  #   price
             |\s*(?:$|\(|Ausverkauft|verlegt)          #   EOL/paren/status
            )
        )
        (?:\s+@\s*(?P<location>(?:{loc_pattern})))?    # @ location
        (?:\s+[*]?(?P<price_prefix>ab\s*)?             # price part (optional)
            (?P<price>\d+(?:[.,]\d{{1,2}})?)\s*€?
        )?
        (?:\s*(?P<status>Ausverkauft!?|verlegt[^\n]*))?  # status (can appear without price)
        """,
        re.VERBOSE | re.UNICODE | re.IGNORECASE,
    )

    resp = requests.get(URL)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.text, "html.parser")

    lines = [t.strip() for t in soup.stripped_strings]

    now = datetime.now()
    events = []
    section = None   # current heading

    for line in lines:
        # Section headings (like "Artheater:")
        if line.endswith(":"):
            section = line[:-1].strip()
            continue

        m = event_pattern.search(line)
        if not m:
            continue

        date, band, loc_at, price, status = m.group("date", "band", "location", "price", "status")

        # prefer explicit @location, else section heading
        location = loc_at if loc_at else (section or "")

        # build proper datetime
        d = datetime.strptime(date + str(now.year), "%d.%m.%Y")
        if d.date() < now.date():  # roll over to next year if already past
            d = d.replace(year=now.year + 1)

        # normalize price
        price_eur = float(price.replace(",", ".")) if price else None

        events.append({
            "origin": line,
            "date": d,
            "band": band.strip(),
            "location": location.strip(),
            "price_eur": price_eur,
            "status": status or "",
        })

        print(f"Parsing line: {band.strip()} on {d.strftime('%d.%m.%Y')} at {location} for {price_eur} EUR {status or ''}")

    # sort chronologically
    # return sorted(events, key=lambda x: x["date"])
    return events

# Example usage
events = fetch_events()
print(f"Parsed {len(events)} events")
# Out:
# loc_pattern: Club\ Bahnhof\ Ehrenfeld|Die\ Hängenden\ Gärten|Vinyl\ Reservierungen|Carlswerk\ Victoria|Stereo\ Wonderland|Allgemeine\ Fragen|Wohngemeinschaft|Live\ Music\ Hall|Stadthalle\ Köln|Underdog\ Shows|Sonic\ Ballroom|Bumann\ \&\ Sohn|Lanxess\ Arena|Kulturkirche|Philharmonie|Tsunami\ Club|Essigfabrik|Stadtgarten|Tanzbrunnen|Blue\ Shell|Club\ Volta|Stollwerck|Artheater|Gebäude\ 9|Helios\ 37|Palladium|Südbrücke|Kantine|E\-Werk|Gloria|Subway|Luxor|Jaki|Yuca|MTC|MTC
# Parsing line: Ritual on 02.10.2025 at Helios 37 for 22.5 EUR
# Parsing line: Duesenjaeger on 03.10.2025 at Gebäude 9 for 24.5 EUR
# Parsing line: Snake Eyes on 15.10.2025 at Stereo Wonderland for 18.0 EUR
# Parsing line: Beach Bunny on 15.10.2025 at Gloria for 33.5 EUR
# Parsing line: ClickClickDecker on 18.10.2025 at Artheater for 27.0 EUR
# Parsing line: Grillmaster Flash on 23.10.2025 at Stereo Wonderland for 20.0 EUR
# Parsing line: DYSE on 04.11.2025 at Gebäude 9 for 29.5 EUR
# Parsing line: Poison Ruin on 06.11.2025 at Club Volta for 25.0 EUR
# Parsing line: Erik Cohen on 08.11.2025 at Gebäude 9 for 28.0 EUR
# Parsing line: Gorilla Biscuits, Terror, No Pressure on 17.11.2025 at Kantine for 41.5 EUR
# Parsing line: Saturdays at your place on 18.01.2026 at Helios 37 for 25.0 EUR
# Parsing line: A.A. Williams on 26.02.2026 at Gebäude 9 for 29.0 EUR
# Parsing line: Kafvka on 13.03.2026 at Gebäude 9 for None EUR
# Parsing line: Masters Of Reality on 02.10.2025 at Artheater for 38.45 EUR
# Parsing line: Bulgarian Cartrader on 07.10.2025 at Artheater for 28.0 EUR
# Parsing line: Power Plush on 10.10.2025 at Artheater for 28.0 EUR
# Parsing line: Sports Team on 12.10.2025 at Artheater for 28.15 EUR
# Parsing line: ClickClickDecker on 18.10.2025 at Artheater for 27.0 EUR
# Parsing line: Loki on 25.10.2025 at Artheater for 25.9 EUR
# Parsing line: Jonny Mahoro on 08.11.2025 at Artheater for 29.2 EUR Ausverkauft!
# Parsing line: Deki Alem on 12.11.2025 at Artheater for 26.4 EUR
# Parsing line: Paula Dalla Corte on 13.11.2025 at Artheater for 28.6 EUR
# Parsing line: Jamie Lawson on 14.11.2025 at Artheater for 30.45 EUR
# Parsing line: Romano on 13.03.2026 at Artheater for 40.65 EUR
# Parsing line: The Haunted Youth on 11.04.2026 at Artheater for 25.3 EUR
# Parsing line: Greg Freeman on 14.09.2026 at Blue Shell for 29.3 EUR
# Parsing line: Boyish on 22.09.2025 at Blue Shell for 24.7 EUR
# Parsing line: Preoccupations on 23.09.2025 at Blue Shell for 28.1 EUR
# Parsing line: Low Island on 27.10.2025 at Blue Shell for 29.2 EUR
# Parsing line: Jasmine.4.t on 02.11.2025 at Blue Shell for 30.45 EUR
# Parsing line: Deep Sea Diver on 03.11.2025 at Blue Shell for 28.15 EUR
# Parsing line: Shirley Holmes on 08.11.2025 at Blue Shell for 23.7 EUR
# Parsing line: The Roystone Club on 19.11.2025 at Blue Shell for 29.3 EUR
# Parsing line: The Pill on 10.12.2025 at Blue Shell for 24.7 EUR
# Parsing line: Pool Kids on 01.03.2026 at Blue Shell for 27.0 EUR
# Parsing line: Man/Woman/Chainsaw on 17.09.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Loving on 18.09.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Sababa on 23.09.2025 at Bumann & Sohn for 5.0 EUR
# Parsing line: Ozan Ata Canani & Die Demokratie on 24.09.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: TV Cult on 07.10.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Sophia Kennedy on 08.10.2025 at Bumann & Sohn for 26.4 EUR verlegt in das Gebäude 9 (Popanz Show)
# Parsing line: False Lefty on 15.10.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Lawn Chair on 22.10.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: U.S. Girls on 03.11.2025 at Bumann & Sohn for 24.2 EUR
# Parsing line: Bachratten on 05.11.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: The Wytches on 12.11.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Upchuck on 18.11.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Julian Knoth on 01.12.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Yuuf on 03.12.2025 at Bumann & Sohn for 18.7 EUR
# Parsing line: The Hidden Cameras on 03.02.2026 at Bumann & Sohn for 29.2 EUR
# Parsing line: Cory Hanson on 10.02.2026 at Bumann & Sohn for 22.0 EUR
# Parsing line: Schramm on 11.02.2026 at Bumann & Sohn for 25.9 EUR
# Parsing line: They Are Gutting A Body Of Water on 19.02.2026 at Bumann & Sohn for 22.0 EUR
# Parsing line: Keshavara on 15.04.2026 at Bumann & Sohn for 22.0 EUR
# Parsing line: Müllem Mon Amour on 20.09.2025 at Carlswerk Victoria for 46.2 EUR
# Parsing line: EivØr on 26.09.2025 at Carlswerk Victoria for 60.9 EUR
# Parsing line: Caamp on 19.10.2025 at Carlswerk Victoria for 44.35 EUR
# Parsing line: Ethel Cain on 21.10.2025 at Carlswerk Victoria for 44.5 EUR Ausverkauft!
# Parsing line: ZSK on 25.10.2025 at Carlswerk Victoria for 58.53 EUR
# Parsing line: The Kiffness on 30.10.2025 at Carlswerk Victoria for 43.5 EUR
# Parsing line: Hell Nights on 31.10.2025 at Carlswerk Victoria for 56.15 EUR
# Parsing line: Mac DeMarco on 04.11.2025 at Carlswerk Victoria for 49.45 EUR Ausverkauft!
# Parsing line: Stray From The Path on 08.11.2025 at Carlswerk Victoria for 44.4 EUR
# Parsing line: Fritz Kalkbrenner on 20.11.2025 at Carlswerk Victoria for 54.4 EUR
# Parsing line: Danko Jones on 11.12.2025 at Carlswerk Victoria for 40.05 EUR
# Parsing line: Dota on 17.12.2025 at Carlswerk Victoria for 41.2 EUR
# Parsing line: Lionheart on 23.01.2026 at Carlswerk Victoria for 49.49 EUR
# Parsing line: Syml on 08.02.2026 at Carlswerk Victoria for 40.05 EUR
# Parsing line: Wizo on 06.03.2026 at Carlswerk Victoria for 51.75 EUR
# Parsing line: Of Monsters and Men on 07.03.2026 at Carlswerk Victoria for 53.3 EUR
# Parsing line: Maximo Park on 08.03.2026 at Carlswerk Victoria for 49.1 EUR
# Parsing line: Betterov on 18.03.2026 at Carlswerk Victoria for 44.5 EUR
# Parsing line: Fatoni on 19.03.2026 at Carlswerk Victoria for 45.25 EUR
# Parsing line: Kanonenfieber on 20.03.2026 at Carlswerk Victoria for 44.7 EUR Ausverkauft!
# Parsing line: Kapelle Petra on 26.03.2026 at Carlswerk Victoria for 39.9 EUR
# Parsing line: Audio88 & Yassin on 19.06.2026 at Carlswerk Victoria for 43.75 EUR
# Parsing line: Those Damn Crows on 03.10.2025 at Club Bahnhof Ehrenfeld for 32.75 EUR Ausverkauft!
# Parsing line: Durand Bernarr on 14.10.2025 at Club Bahnhof Ehrenfeld for 29.3 EUR
# Parsing line: Monophonics on 26.10.2025 at Club Bahnhof Ehrenfeld for 29.2 EUR
# Parsing line: Chris James on 15.10.2025 at Club Bahnhof Ehrenfeld for 29.3 EUR
# Parsing line: McLusky on 13.11.2025 at Club Bahnhof Ehrenfeld for 27.5 EUR
# Parsing line: Obongjayar on 16.11.2025 at Club Bahnhof Ehrenfeld for 31.6 EUR
# Parsing line: John Maus on 19.11.2025 at Club Bahnhof Ehrenfeld for 29.2 EUR
# Parsing line: Chefket on 20.11.2025 at Club Bahnhof Ehrenfeld for 35.7 EUR
# Parsing line: Benjrose on 27.11.2025 at Club Bahnhof Ehrenfeld for 32.75 EUR
# Parsing line: Tristan Brusch on 11.03.2026 at Club Bahnhof Ehrenfeld for 32.0 EUR
# Parsing line: The Magic Mumble Jumble on 29.03.2026 at Club Bahnhof Ehrenfeld for 35.9 EUR
# Parsing line: Henge on 13.04.2026 at Club Bahnhof Ehrenfeld for 29.2 EUR
# Parsing line: Dari on 28.11.2025 at Club Bahnhof Ehrenfeld for 34.9 EUR
# Parsing line: Better Lovers on 26.09.2025 at Club Volta for 32.75 EUR
# Parsing line: Jeffrey Lewis on 30.09.2025 at Club Volta for 26.96 EUR
# Parsing line: The Vintage Caravan on 03.10.2025 at Club Volta for 32.5 EUR
# Parsing line: The Obsessed on 15.10.2025 at Club Volta for 29.2 EUR
# Parsing line: Castle Rat on 21.10.2025 at Club Volta for 29.2 EUR
# Parsing line: Leftovers on 25.10.2025 at Club Volta for 28.6 EUR
# Parsing line: Poison Ruin on 06.11.2025 at Club Volta for 25.0 EUR
# Parsing line: The Summer Set on 07.11.2025 at Club Volta for 31.6 EUR
# Parsing line: Kochkraft durch KMA on 08.11.2025 at Club Volta for 28.35 EUR
# Parsing line: Booze & Glory on 14.11.2025 at Club Volta for 34.7 EUR
# Parsing line: The Young Gods on 17.11.2025 at Club Volta for 31.8 EUR
# Parsing line: Mother Tongue on 25.11.2025 at Club Volta for 33.6 EUR
# Parsing line: Rise Of The Northstar on 09.12.2025 at Club Volta for 44.5 EUR
# Parsing line: Deaf Havana on 29.01.2026 at Club Volta for 31.6 EUR
# Parsing line: Schmutzki on 12.03.2026 at Club Volta for 38.45 EUR
# Parsing line: We Came As Romans on 04.10.2025 at Essigfabrik for 47.9 EUR
# Parsing line: Nasty on 11.10.2025 at Essigfabrik for 37.0 EUR
# Parsing line: Jaill on 18.10.2025 at Essigfabrik for 39.4 EUR
# Parsing line: Curtis Harding on 04.11.2025 at Essigfabrik for 44.25 EUR
# Parsing line: Guilt Trip on 28.11.2025 at Essigfabrik for 33.75 EUR
# Parsing line: Chelsea Grin on 30.11.2025 at Essigfabrik for 43.35 EUR
# Parsing line: Of Mice And Men on 05.12.2025 at Essigfabrik for 42.4 EUR
# Parsing line: HGich.T on 16.01.2026 at Essigfabrik for 34.7 EUR
# Parsing line: Earl Sweatshirt on 08.02.2026 at Essigfabrik for 46.4 EUR
# Parsing line: Mobb Deep on 16.04.2026 at Essigfabrik for 44.0 EUR
# Parsing line: Oxo on 19.12.2025 at Essigfabrik for 86.0 EUR
# Parsing line: Lord Huron on 15.09.2026 at E-Werk for 43.5 EUR Ausverkauft!
# Parsing line: The Cat Empire on 06.10.2025 at E-Werk for 49.25 EUR
# Parsing line: Larkin Poe on 26.10.2025 at E-Werk for 55.75 EUR
# Parsing line: Skindred on 16.11.2025 at E-Werk for 44.65 EUR
# Parsing line: Big Thief on 14.04.2026 at E-Werk for 54.24 EUR
# Parsing line: Moneybrother on 13.09.2026 at Gebäude 9 for 38.2 EUR Ausverkauft!
# Parsing line: Richy Mitch & The Coal Miners on 14.09.2026 at Gebäude 9 for 32.75 EUR
# Parsing line: Ten56. on 18.09.2025 at Gebäude 9 for 31.6 EUR
# Parsing line: Poison The Well on 19.09.2025 at Gebäude 9 for 46.95 EUR Ausverkauft!
# Parsing line: Young Rebel Set on 20.09.2025 at Gebäude 9 for 37.2 EUR
# Parsing line: Darkest Hour on 26.09.2025 at Gebäude 9 for 40.85 EUR
# Parsing line: Malou Lovis on 29.09.2025 at Gebäude 9 for 29.0 EUR
# Parsing line: Shame on 30.09.2025 at Gebäude 9 for 35.9 EUR
# Parsing line: Zoot Woman on 02.10.2025 at Gebäude 9 for 35.9 EUR
# Parsing line: Duesenjaeger on 03.10.2025 at Gebäude 9 for 24.5 EUR
# Parsing line: Witch Club Satan on 05.10.2025 at Gebäude 9 for 26.96 EUR Ausverkauft!
# Parsing line: Sharktank on 07.10.2025 at Gebäude 9 for 34.9 EUR
# Parsing line: Sophia Kennedy on 08.10.2025 at Gebäude 9 for 26.4 EUR verlegt vom Bumann & Sohn (Popanz Show)
# Parsing line: Starsailor on 10.10.2025 at Gebäude 9 for 34.7 EUR Ausverkauft!
# Parsing line: Inspector Cluzo on 11.10.2025 at Gebäude 9 for 30.45 EUR
# Parsing line: bac on 15.10.2025 at Gebäude 9 for 30.0 EUR
# Parsing line: L.A. Salami on 16.10.2025 at Gebäude 9 for 27.5 EUR
# Parsing line: As December Falls on 17.10.2025 at Gebäude 9 for 30.7 EUR
# Parsing line: Orannsi Pazuzu on 18.10.2025 at Gebäude 9 for 30.37 EUR
# Parsing line: Joya Marleen on 20.10.2025 at Gebäude 9 for 26.0 EUR
# Parsing line: Herrenmagazin on 23.10.2025 at Gebäude 9 for 27.7 EUR Ausverkauft!
# Parsing line: Drei Meter Feldweg on 24.10.2025 at Gebäude 9 for 30.2 EUR
# Parsing line: Augn on 25.10.2025 at Gebäude 9 for 28.1 EUR
# Parsing line: Alarmsignal on 01.11.2025 at Gebäude 9 for 30.95 EUR
# Parsing line: Hotel Rimini on 02.11.2025 at Gebäude 9 for 27.5 EUR
# Parsing line: Roya on 03.11.2025 at Gebäude 9 for 33.9 EUR
# Parsing line: DYSE on 04.11.2025 at Gebäude 9 for 29.5 EUR
# Parsing line: Easy Easy on 05.11.2025 at Gebäude 9 for 25.9 EUR
# Parsing line: Foxwarren on 06.11.2025 at Gebäude 9 for 30.45 EUR
# Parsing line: Pogendroblem on 07.11.2025 at Gebäude 9 for 24.2 EUR
# Parsing line: Erik Cohen on 08.11.2025 at Gebäude 9 for 28.0 EUR
# Parsing line: Ghostwoman on 10.11.2025 at Gebäude 9 for 27.5 EUR
# Parsing line: King Hannah on 11.11.2025 at Gebäude 9 for 29.2 EUR
# Parsing line: McLusky on 13.11.2025 at Gebäude 9 for 27.5 EUR
# Parsing line: Cate Le Bon on 14.11.2025 at Gebäude 9 for 29.7 EUR
# Parsing line: Balthvs on 15.11.2025 at Gebäude 9 for 37.2 EUR
# Parsing line: Mono on 17.11.2025 at Gebäude 9 for 34.7 EUR
# Parsing line: Minami Deutsch on 18.11.2025 at Gebäude 9 for 26.4 EUR
# Parsing line: Van Holzen on 20.11.2025 at Gebäude 9 for 29.1 EUR
# Parsing line: Marathonmann on 21.11.2025 at Gebäude 9 for 29.8 EUR
# Parsing line: Matt Anderson on 23.11.2025 at Gebäude 9 for 34.7 EUR
# Parsing line: Frankie And The Witchfingers on 25.11.2025 at Gebäude 9 for 25.3 EUR
# Parsing line: Friso on 01.12.2025 at Gebäude 9 for 33.7 EUR
# Parsing line: Lambrini Girls on 07.12.2025 at Gebäude 9 for None EUR
# Parsing line: The Meteors on 09.12.2025 at Gebäude 9 for 31.95 EUR
# Parsing line: Iedereen on 11.12.2025 at Gebäude 9 for 24.2 EUR
# Parsing line: Extrabreit on 12.12.2025 at Gebäude 9 for 44.85 EUR
# Parsing line: KMPFSPRT on 13.12.2025 at Gebäude 9 for 24.2 EUR
# Parsing line: Loathe on 14.12.2025 at Gebäude 9 for 37.3 EUR
# Parsing line: Bernd Begemann on 27.12.2025 at Gebäude 9 for 22.0 EUR
# Parsing line: Born Of Osiris on 09.01.2026 at Gebäude 9 for 42.95 EUR
# Parsing line: Demented Are Go on 10.01.2026 at Gebäude 9 for 32.95 EUR
# Parsing line: Pabst on 23.01.2026 at Gebäude 9 for 27.5 EUR
# Parsing line: Nanowar Of Steel on 29.01.2026 at Gebäude 9 for 40.7 EUR
# Parsing line: Kontrollverlust on 31.01.2026 at Gebäude 9 for 32.4 EUR
# Parsing line: Anna Von Hausswolff on 04.02.2026 at Gebäude 9 for 32.75 EUR
# Parsing line: Arms Lenght on 20.02.2026 at Gebäude 9 for 33.35 EUR
# Parsing line: Elwood Stray & Our Mirage on 21.02.2026 at Gebäude 9 for 28.95 EUR
# Parsing line: Rosmarin on 22.02.2026 at Gebäude 9 for 30.7 EUR
# Parsing line: A.A. Williams on 26.02.2026 at Gebäude 9 for 29.0 EUR
# Parsing line: Good Neighbours on 03.03.2026 at Gebäude 9 for 33.9 EUR
# Parsing line: Kafvka on 13.03.2026 at Gebäude 9 for 31.3 EUR
# Parsing line: Spidergawd on 17.03.2026 at Gebäude 9 for 41.5 EUR
# Parsing line: Kapa Tult on 18.03.2026 at Gebäude 9 for 27.5 EUR
# Parsing line: Doctor Krapula on 27.03.2026 at Gebäude 9 for 26.4 EUR
# Parsing line: Full Of Hell, The Body on 04.04.2026 at Gebäude 9 for 33.77 EUR
# Parsing line: Lansdowne on 16.04.2026 at Gebäude 9 for 29.1 EUR
# Parsing line: The Toten Crackhuren im Kofferraum on 17.04.2026 at Gebäude 9 for 33.5 EUR
# Parsing line: Hundreds on 21.04.2026 at Gebäude 9 for 42.75 EUR
# Parsing line: Salò on 07.05.2026 at Gebäude 9 for 33.8 EUR
# Parsing line: Hardline on 08.05.2026 at Gebäude 9 for 41.5 EUR
# Parsing line: Rami Hattab on 30.05.2026 at Gebäude 9 for 34.7 EUR
# Parsing line: Hooverphonic on 06.10.2025 at Gloria for 51.7 EUR
# Parsing line: Black Country, New Road on 14.10.2025 at Gloria for 35.2 EUR
# Parsing line: Beach Bunny on 15.10.2025 at Gloria for 33.5 EUR
# Parsing line: Die Höchste Eisenbahn on 01.12.2025 at Gloria for 42.2 EUR Ausverkauft!
# Parsing line: Erdmöbel on 22.12.2025 at Gloria for 35.1 EUR
# Parsing line: Yin Yin on 05.03.2026 at Gloria for 29.8 EUR
# Parsing line: Black Sea Dahu on 01.04.2026 at Gloria for 41.85 EUR
# Parsing line: Milliarden on 02.04.2026 at Gloria for 39.9 EUR
# Parsing line: Herrenmagazin on 10.12.2025 at Gloria for 41.05 EUR
# Parsing line: Caleb Hearn on 23.09.2025 at Helios 37 for 29.3 EUR
# Parsing line: Blondshell on 25.09.2025 at Helios 37 for 30.3 EUR Ausverkauft!
# Parsing line: Rachel Grae on 01.10.2025 at Helios 37 for 23.55 EUR
# Parsing line: Ritual on 02.10.2025 at Helios 37 for 22.5 EUR
# Parsing line: Hellsongs on 09.10.2025 at Helios 37 for 25.9 EUR
# Parsing line: Tim Vantol on 11.10.2025 at Helios 37 for 35.7 EUR
# Parsing line: Catapults on 16.10.2025 at Helios 37 for 23.7 EUR
# Parsing line: The Vices on 26.10.2025 at Helios 37 for 27.6 EUR
# Parsing line: Greyscale on 09.11.2025 at Helios 37 for 30.55 EUR
# Parsing line: Softcult on 18.11.2025 at Helios 37 for 25.85 EUR
# Parsing line: Swim School on 22.11.2025 at Helios 37 for 28.15 EUR
# Parsing line: Pudeldame on 25.11.2025 at Helios 37 for 28.1 EUR
# Parsing line: Sparkling on 28.11.2025 at Helios 37 for 22.0 EUR
# Parsing line: Slow Crush on 30.11.2025 at Helios 37 for 30.7 EUR
# Parsing line: Saturdays at your place on 18.01.2026 at Helios 37 for 25.0 EUR
# Parsing line: Still Talk on 24.01.2026 at Helios 37 for 25.9 EUR
# Parsing line: Eläkeläiset on 20.04.2026 at Helios 37 for 30.3 EUR
# Parsing line: Hohnen Ford on 05.10.2025 at Jaki for 29.15 EUR
# Parsing line: Ende on 15.10.2025 at Jaki for 23.7 EUR
# Parsing line: Afar on 24.10.2025 at Jaki for 22.0 EUR
# Parsing line: Ethan Regan on 07.12.2025 at Jaki for 28.15 EUR
# Parsing line: David Bay on 08.12.2025 at Jaki for 23.7 EUR
# Parsing line: Dope Lemon on 15.09.2026 at Kantine for 47.8 EUR
# Parsing line: Umse on 27.09.2025 at Kantine for 34.7 EUR
# Parsing line: Siena Root on 02.10.2025 at Kantine for 27.0 EUR
# Parsing line: The Beths on 03.10.2025 at Kantine for 27.5 EUR
# Parsing line: The Pharcyde on 16.10.2025 at Kantine for 55.1 EUR
# Parsing line: Anda Morts on 28.10.2025 at Kantine for 30.3 EUR
# Parsing line: Everything Everything on 03.11.2025 at Kantine for 36.2 EUR
# Parsing line: Gorilla Biscuits, Terror, No Pressure on 17.11.2025 at Kantine for 41.5 EUR
# Parsing line: Baxter Dury on 27.11.2025 at Kantine for 44.65 EUR
# Parsing line: Lambrini Girls on 07.12.2025 at Kantine for 27.5 EUR
# Parsing line: Slime on 23.01.2026 at Kantine for 44.9 EUR
# Parsing line: Tortoise on 27.01.2026 at Kantine for 42.4 EUR
# Parsing line: Blossoms on 10.02.2026 at Kantine for 33.9 EUR
# Parsing line: Sprints on 14.03.2026 at Kantine for 33.9 EUR
# Parsing line: Geese on 18.03.2026 at Kantine for 30.45 EUR
# Parsing line: Godspeed You! Black Emperor on 20.03.2026 at Kantine for 41.87 EUR
# Parsing line: She Past Away on 08.05.2026 at Kantine for 40.77 EUR
# Parsing line: Bonaparte on 29.10.2025 at Kantine for 47.25 EUR
# Parsing line: Betterov on 15.10.2025 at Kulturkirche for 44.5 EUR Ausverkauft!
# Parsing line: Jadu Heart on 04.11.2025 at Kulturkirche for 37.2 EUR
# Parsing line: Becky Sikasa on 07.11.2025 at Kulturkirche for 27.5 EUR
# Parsing line: Steiner & Madlaina on 11.11.2025 at Kulturkirche for 44.5 EUR
# Parsing line: Cara Rose on 13.11.2025 at Kulturkirche for 29.2 EUR
# Parsing line: Fil Bo Riva on 19.11.2025 at Kulturkirche for 47.25 EUR
# Parsing line: Fortuna Ehrenfeld on 09.12.2025 at Kulturkirche for 44.63 EUR
# Parsing line: Fortuna Ehrenfeld on 10.12.2025 at Kulturkirche for 44.63 EUR
# Parsing line: Bob Dylan on 03.11.2025 at Lanxess Arena for 70.0 EUR
# Parsing line: Nina Chuba on 06.11.2025 at Lanxess Arena for 52.9 EUR Ausverkauft!
# Parsing line: Gogol Bordello on 13.09.2026 at Live Music Hall for 46.95 EUR
# Parsing line: Mogwai on 20.09.2025 at Live Music Hall for 50.32 EUR
# Parsing line: Basement on 26.09.2025 at Live Music Hall for 35.9 EUR
# Parsing line: The Midnight on 28.09.2025 at Live Music Hall for 43.5 EUR Ausverkauft!
# Parsing line: Igorrr on 12.10.2025 at Live Music Hall for 44.5 EUR
# Parsing line: Atreyu on 18.10.2025 at Live Music Hall for 46.95 EUR
# Parsing line: Banks on 20.10.2025 at Live Music Hall for 47.0 EUR
# Parsing line: Paradise Lost on 23.10.2025 at Live Music Hall for 49.25 EUR
# Parsing line: Jonny Maar on 26.10.2025 at Live Music Hall for 45.05 EUR
# Parsing line: Kadavar on 28.10.2025 at Live Music Hall for 44.5 EUR
# Parsing line: The Darkness on 30.10.2025 at Live Music Hall for 44.65 EUR
# Parsing line: Arrested Development on 02.11.2025 at Live Music Hall for 55.0 EUR
# Parsing line: Kae Tempest on 03.11.2025 at Live Music Hall for 49.28 EUR
# Parsing line: Malevolence on 05.11.2025 at Live Music Hall for 47.0 EUR
# Parsing line: John Butler on 08.11.2025 at Live Music Hall for 45.0 EUR
# Parsing line: Noga Erez on 23.11.2025 at Live Music Hall for 45.0 EUR
# Parsing line: Joy Crookes on 29.11.2025 at Live Music Hall for 41.8 EUR
# Parsing line: Clutch on 10.12.2025 at Live Music Hall for 43.5 EUR
# Parsing line: Counterparts on 05.02.2026 at Live Music Hall for 44.4 EUR
# Parsing line: White Lies on 24.02.2026 at Live Music Hall for 46.95 EUR
# Parsing line: La Dispute on 10.03.2026 at Live Music Hall for 35.05 EUR
# Parsing line: Prinz Pi on 11.10.2025 at Live Music Hall for 52.79 EUR
# Parsing line: Nova Twins on 21.09.2025 at Luxor for 28.15 EUR
# Parsing line: Billie Marten on 02.11.2025 at Luxor for 30.45 EUR
# Parsing line: Flipturn on 04.11.2025 at Luxor for 30.45 EUR
# Parsing line: Destroyer + The Weather Station on 08.11.2025 at Luxor for 34.7 EUR
# Parsing line: Skinny Lister on 29.11.2025 at Luxor for 32.75 EUR
# Parsing line: Deaf Havana on 23.01.2026 at Luxor for 30.45 EUR Ausverkauft!
# Parsing line: Teenage Dads on 17.09.2025 at MTC for 28.15 EUR
# Parsing line: L.A. Witch on 30.09.2025 at MTC for 30.45 EUR
# Parsing line: Big Special on 28.10.2025 at MTC for 32.6 EUR Ausverkauft!
# Parsing line: Triggerfinger on 12.11.2025 at MTC for 32.5 EUR
# Parsing line: Sons on 22.11.2025 at MTC for 27.0 EUR
# Parsing line: Florence Black on 26.11.2025 at MTC for 30.6 EUR
# Parsing line: The Scratch on 27.11.2025 at MTC for 30.45 EUR
# Parsing line: Deviloof on 02.12.2025 at MTC for 47.65 EUR
# Parsing line: Militarie Gun on 30.01.2026 at MTC for 30.45 EUR
# Parsing line: The Aces on 11.02.2026 at MTC for 31.6 EUR
# Parsing line: Tulpe on 21.02.2026 at MTC for 29.4 EUR
# Parsing line: Coach Party on 28.02.2026 at MTC for 27.0 EUR
# Parsing line: Indie Cologne Fest on 21.09.2025 at MTC for 17.6 EUR
# Parsing line: Little Simz on 29.09.2025 at Palladium for 56.75 EUR Ausverkauft!
# Parsing line: Meute on 02.10.2025 at Palladium for 59.35 EUR
# Parsing line: Loyle Carner on 22.10.2025 at Palladium for 68.25 EUR
# Parsing line: OG Keemo on 25.10.2025 at Palladium for 44.49 EUR Ausverkauft!
# Parsing line: Von Wegen Lisbeth on 01.11.2025 at Palladium for 48.0 EUR
# Parsing line: H-Blockx on 02.11.2025 at Palladium for 58.7 EUR
# Parsing line: Dropkick Murphys on 03.11.2025 at Palladium for 67.9 EUR
# Parsing line: Dropkick Murphys on 04.11.2025 at Palladium for 67.9 EUR
# Parsing line: Wolf Alice on 17.11.2025 at Palladium for 45.25 EUR
# Parsing line: Blond on 18.11.2025 at Palladium for 47.4 EUR
# Parsing line: Killwitch Engage on 20.11.2025 at Palladium for 59.0 EUR
# Parsing line: Mine on 25.11.2025 at Palladium for 61.9 EUR
# Parsing line: The Hives on 01.12.2025 at Palladium for 57.55 EUR
# Parsing line: Royal Otis on 08.12.2025 at Palladium for 47.0 EUR
# Parsing line: Landmvrks on 19.12.2025 at Palladium for 56.45 EUR
# Parsing line: Jinjer on 23.01.2026 at Palladium for 51.25 EUR
# Parsing line: Heaven Shall Burn on 28.02.2026 at Palladium for 69.4 EUR
# Parsing line: Franz Ferdinand on 04.04.2026 at Palladium for 62.5 EUR
# Parsing line: Kaffkiez on 12.04.2026 at Palladium for 54.4 EUR
# Parsing line: Sportfreunde Stiller on 11.05.2026 at Palladium for 53.85 EUR
# Parsing line: Fortuna Ehrenfeld on 22.10.2025 at Philharmonie for 28.5 EUR
# Parsing line: Fortuna Ehrenfeld on 23.10.2025 at Philharmonie for 28.5 EUR Ausverkauft!
# Parsing line: Toxoplasma on 12.09.2026 at Sonic Ballroom for 16.5 EUR Ausverkauft!
# Parsing line: The Slapstickers on 13.09.2026 at Sonic Ballroom for 17.6 EUR
# Parsing line: Lord Rochester on 16.09.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Popperklopper on 19.09.2025 at Sonic Ballroom for 14.3 EUR
# Parsing line: The Vovos on 20.09.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: Violencia on 24.09.2025 at Sonic Ballroom for 14.3 EUR
# Parsing line: Guts Pie Earshot on 25.09.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: Bratakus on 26.09.2025 at Sonic Ballroom for 14.3 EUR
# Parsing line: The Tips on 02.10.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: Hamburger Spinners on 04.10.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Negative Blast on 08.10.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: Karaoke Till Death on 09.10.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Karaoke Till Death on 10.10.2025 at Sonic Ballroom for 16.5 EUR Ausverkauft!
# Parsing line: The Backyard Band on 18.10.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: The Quakes on 29.10.2025 at Sonic Ballroom for 17.6 EUR
# Parsing line: Banana Peel Slippers on 01.11.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Bazooka Zirkus on 07.11.2025 at Sonic Ballroom for 14.3 EUR
# Parsing line: The Turbo A.C.s on 13.11.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Der Dumme August on 14.11.2025 at Sonic Ballroom for 14.3 EUR
# Parsing line: The Darts on 18.11.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Sedlmeir on 20.11.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: Karoshi on 21.11.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: The Schizophonics on 22.11.2025 at Sonic Ballroom for 17.6 EUR
# Parsing line: Long Tall Texans on 26.11.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Nichts on 05.12.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Jesper Munk on 15.10.2025 at Stadtgarten for 31.4 EUR
# Parsing line: The Rural Alberta Advantage on 10.12.2025 at Stadtgarten for 35.0 EUR
# Parsing line: Grandbrothers on 01.11.2025 at Stadthalle Köln for 41.6 EUR
# Parsing line: Erobique on 30.12.2025 at Stadthalle Köln for 42.2 EUR
# Parsing line: Divine Comedy on 15.03.2026 at Stadthalle Köln for 53.9 EUR Ausverkauft!
# Parsing line: Belle & Sebastian performing Tigermilk on 17.03.2026 at Stadthalle Köln for 55.0 EUR
# Parsing line: Belle & Sebastian performing If You’re Feeling Sinister on 18.03.2026 at Stadthalle Köln for 55.0 EUR
# Parsing line: JNSN on 27.09.2025 at Stereo Wonderland for 21.0 EUR
# Parsing line: Sick Fizz on 09.10.2025 at Stereo Wonderland for 17.88 EUR
# Parsing line: Snake Eyes on 15.10.2025 at Stereo Wonderland for 18.0 EUR
# Parsing line: Grillmaster Flash on 23.10.2025 at Stereo Wonderland for 20.0 EUR
# Parsing line: Drangsal on 27.09.2025 at Stollwerck for 41.75 EUR
# Parsing line: K’s Choice on 08.10.2025 at Stollwerck for 52.95 EUR
# Parsing line: Refused on 10.10.2025 at Stollwerck for 49.45 EUR Ausverkauft!
# Parsing line: Coheed And Cambria on 11.10.2025 at Stollwerck for 44.5 EUR Ausverkauft!
# Parsing line: Mantar on 24.10.2025 at Stollwerck for 34.7 EUR
# Parsing line: The Subways on 24.11.2025 at Stollwerck for 40.05 EUR
# Parsing line: Deus on 24.03.2026 at Stollwerck for 51.0 EUR
# Parsing line: Nickless on 29.10.2025 at Subway for 29.1 EUR
# Parsing line: Neon Dreams on 12.11.2025 at Subway for 25.9 EUR
# Parsing line: Donots on 19.09.2025 at Südbrücke for 52.75 EUR
# Parsing line: Antilopden Gang on 20.09.2025 at Südbrücke for 53.05 EUR
# Parsing line: Soap & Skin on 17.10.2025 at Tanzbrunnen for 49.45 EUR
# Parsing line: RedHook on 10.05.2026 at Tsunami Club for 25.8 EUR
# Parsing line: Bulgarian Cartrader on 07.10.2025 at Tsunami Club for 28.0 EUR
# Parsing line: Mar Malade on 03.10.2025 at Wohngemeinschaft for 23.7 EUR Ausverkauft!
# Parsing line: Bertie Newman on 26.11.2025 at Wohngemeinschaft for 25.9 EUR
# Parsing line: Chloe Moriondo on 15.09.2026 at Yuca for 30.45 EUR
# Parsing line: Sofie Royer on 22.09.2025 at Yuca for 25.9 EUR
# Parsing line: Kings Elliot on 11.10.2025 at Yuca for 33.3 EUR
# Parsing line: Great Grandpa on 05.11.2025 at Yuca for 30.45 EUR
# Parsing line: Panic Shack on 22.11.2025 at Yuca for 30.3 EUR
# Parsing line: Jerub on 28.11.2025 at Yuca for 33.9 EUR
# Parsing line: Big Sleep on 02.12.2025 at Yuca for 28.15 EUR
# Parsing line: Noso on 10.02.2026 at Yuca for 24.7 EUR
# Parsed 374 events

# %%
events = fetch_events()

len(events)

events[:5]
# Out:
# Parsing line: Ritual on 02.10.2025 at Helios for 37.0 EUR
# Parsing line: Duesenjaeger on 03.10.2025 at Gebäude for 9.0 EUR
# Parsing line: Snake Eyes on 15.10.2025 at Stereo Wonderland for 18.0 EUR
# Parsing line: Beach Bunny on 15.10.2025 at Gloria for 33.5 EUR
# Parsing line: ClickClickDecker on 18.10.2025 at Artheater for 27.0 EUR
# Parsing line: Grillmaster Flash on 23.10.2025 at Stereo Wonderland for 20.0 EUR
# Parsing line: DYSE on 04.11.2025 at Gebäude for 9.0 EUR
# Parsing line: Poison Ruin on 06.11.2025 at Club Volta for 25.0 EUR
# Parsing line: Erik Cohen on 08.11.2025 at Gebäude for 9.0 EUR
# Parsing line: Gorilla Biscuits, Terror, No Pressure on 17.11.2025 at Kantine for 41.5 EUR
# Parsing line: Saturdays at your place on 18.01.2026 at Helios for 37.0 EUR
# Parsing line: A.A. Williams on 26.02.2026 at Gebäude for 9.0 EUR
# Parsing line: Kafvka on 13.03.2026 at Gebäude for 9.0 EUR
# Parsing line: Masters Of Reality on 02.10.2025 at Artheater for 38.45 EUR
# Parsing line: Bulgarian Cartrader on 07.10.2025 at Artheater for 28.0 EUR
# Parsing line: Power Plush on 10.10.2025 at Artheater for 28.0 EUR
# Parsing line: Sports Team on 12.10.2025 at Artheater for 28.15 EUR
# Parsing line: ClickClickDecker on 18.10.2025 at Artheater for 27.0 EUR
# Parsing line: Loki on 25.10.2025 at Artheater for 25.9 EUR
# Parsing line: Jonny Mahoro on 08.11.2025 at Artheater for 29.2 EUR Ausverkauft!
# Parsing line: Deki Alem on 12.11.2025 at Artheater for 26.4 EUR
# Parsing line: Paula Dalla Corte on 13.11.2025 at Artheater for 28.6 EUR
# Parsing line: Jamie Lawson on 14.11.2025 at Artheater for 30.45 EUR
# Parsing line: Romano on 13.03.2026 at Artheater for 40.65 EUR
# Parsing line: The Haunted Youth on 11.04.2026 at Artheater for 25.3 EUR
# Parsing line: Greg Freeman on 14.09.2025 at Blue Shell for 29.3 EUR
# Parsing line: Boyish on 22.09.2025 at Blue Shell for 24.7 EUR
# Parsing line: Preoccupations on 23.09.2025 at Blue Shell for 28.1 EUR
# Parsing line: Low Island on 27.10.2025 at Blue Shell for 29.2 EUR
# Parsing line: Jasmine.4.t on 02.11.2025 at Blue Shell for 30.45 EUR
# Parsing line: Deep Sea Diver on 03.11.2025 at Blue Shell for 28.15 EUR
# Parsing line: Shirley Holmes on 08.11.2025 at Blue Shell for 23.7 EUR
# Parsing line: The Roystone Club on 19.11.2025 at Blue Shell for 29.3 EUR
# Parsing line: The Pill on 10.12.2025 at Blue Shell for 24.7 EUR
# Parsing line: Pool Kids on 01.03.2026 at Blue Shell for 27.0 EUR
# Parsing line: Man/Woman/Chainsaw on 17.09.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Loving on 18.09.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Sababa on 23.09.2025 at Bumann & Sohn for 5.0 EUR
# Parsing line: Ozan Ata Canani & Die Demokratie on 24.09.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: TV Cult on 07.10.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Sophia Kennedy on 08.10.2025 at Bumann & Sohn for 26.4 EUR verlegt in das Gebäude 9 (Popanz Show)
# Parsing line: False Lefty on 15.10.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Lawn Chair on 22.10.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: U.S. Girls on 03.11.2025 at Bumann & Sohn for 24.2 EUR
# Parsing line: Bachratten on 05.11.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: The Wytches on 12.11.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Upchuck on 18.11.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Julian Knoth on 01.12.2025 at Bumann & Sohn for 19.8 EUR
# Parsing line: Yuuf on 03.12.2025 at Bumann & Sohn for 18.7 EUR
# Parsing line: The Hidden Cameras on 03.02.2026 at Bumann & Sohn for 29.2 EUR
# Parsing line: Cory Hanson on 10.02.2026 at Bumann & Sohn for 22.0 EUR
# Parsing line: Schramm on 11.02.2026 at Bumann & Sohn for 25.9 EUR
# Parsing line: They Are Gutting A Body Of Water on 19.02.2026 at Bumann & Sohn for 22.0 EUR
# Parsing line: Keshavara on 15.04.2026 at Bumann & Sohn for 22.0 EUR
# Parsing line: Müllem Mon Amour on 20.09.2025 at Carlswerk Victoria for 46.2 EUR
# Parsing line: EivØr on 26.09.2025 at Carlswerk Victoria for 60.9 EUR
# Parsing line: Caamp on 19.10.2025 at Carlswerk Victoria for 44.35 EUR
# Parsing line: Ethel Cain on 21.10.2025 at Carlswerk Victoria for 44.5 EUR Ausverkauft!
# Parsing line: ZSK on 25.10.2025 at Carlswerk Victoria for 58.53 EUR
# Parsing line: The Kiffness on 30.10.2025 at Carlswerk Victoria for 43.5 EUR
# Parsing line: Hell Nights on 31.10.2025 at Carlswerk Victoria for 56.15 EUR
# Parsing line: Mac DeMarco on 04.11.2025 at Carlswerk Victoria for 49.45 EUR Ausverkauft!
# Parsing line: Stray From The Path on 08.11.2025 at Carlswerk Victoria for 44.4 EUR
# Parsing line: Fritz Kalkbrenner on 20.11.2025 at Carlswerk Victoria for 54.4 EUR
# Parsing line: Danko Jones on 11.12.2025 at Carlswerk Victoria for 40.05 EUR
# Parsing line: Dota on 17.12.2025 at Carlswerk Victoria for 41.2 EUR
# Parsing line: Lionheart on 23.01.2026 at Carlswerk Victoria for 49.49 EUR
# Parsing line: Syml on 08.02.2026 at Carlswerk Victoria for 40.05 EUR
# Parsing line: Wizo on 06.03.2026 at Carlswerk Victoria for 51.75 EUR
# Parsing line: Of Monsters and Men on 07.03.2026 at Carlswerk Victoria for 53.3 EUR
# Parsing line: Maximo Park on 08.03.2026 at Carlswerk Victoria for 49.1 EUR
# Parsing line: Betterov on 18.03.2026 at Carlswerk Victoria for 44.5 EUR
# Parsing line: Fatoni on 19.03.2026 at Carlswerk Victoria for 45.25 EUR
# Parsing line: Kanonenfieber on 20.03.2026 at Carlswerk Victoria for 44.7 EUR Ausverkauft!
# Parsing line: Kapelle Petra on 26.03.2026 at Carlswerk Victoria for 39.9 EUR
# Parsing line: Audio88 & Yassin on 19.06.2026 at Carlswerk Victoria for 43.75 EUR
# Parsing line: Those Damn Crows on 03.10.2025 at Club Bahnhof Ehrenfeld for 32.75 EUR Ausverkauft!
# Parsing line: Durand Bernarr on 14.10.2025 at Club Bahnhof Ehrenfeld for 29.3 EUR
# Parsing line: Monophonics on 26.10.2025 at Club Bahnhof Ehrenfeld for 29.2 EUR
# Parsing line: Chris James on 15.10.2025 at Club Bahnhof Ehrenfeld for 29.3 EUR
# Parsing line: McLusky on 13.11.2025 at Club Bahnhof Ehrenfeld for 27.5 EUR
# Parsing line: Obongjayar on 16.11.2025 at Club Bahnhof Ehrenfeld for 31.6 EUR
# Parsing line: John Maus on 19.11.2025 at Club Bahnhof Ehrenfeld for 29.2 EUR
# Parsing line: Chefket on 20.11.2025 at Club Bahnhof Ehrenfeld for 35.7 EUR
# Parsing line: Benjrose on 27.11.2025 at Club Bahnhof Ehrenfeld for 32.75 EUR
# Parsing line: Tristan Brusch on 11.03.2026 at Club Bahnhof Ehrenfeld for 32.0 EUR
# Parsing line: The Magic Mumble Jumble on 29.03.2026 at Club Bahnhof Ehrenfeld for 35.9 EUR
# Parsing line: Henge on 13.04.2026 at Club Bahnhof Ehrenfeld for 29.2 EUR
# Parsing line: Dari on 28.11.2025 at Club Bahnhof Ehrenfeld for 34.9 EUR
# Parsing line: Better Lovers on 26.09.2025 at Club Volta for 32.75 EUR
# Parsing line: Jeffrey Lewis on 30.09.2025 at Club Volta for 26.96 EUR
# Parsing line: The Vintage Caravan on 03.10.2025 at Club Volta for 32.5 EUR
# Parsing line: The Obsessed on 15.10.2025 at Club Volta for 29.2 EUR
# Parsing line: Castle Rat on 21.10.2025 at Club Volta for 29.2 EUR
# Parsing line: Leftovers on 25.10.2025 at Club Volta for 28.6 EUR
# Parsing line: Poison Ruin on 06.11.2025 at Club Volta for 25.0 EUR
# Parsing line: The Summer Set on 07.11.2025 at Club Volta for 31.6 EUR
# Parsing line: Kochkraft durch KMA on 08.11.2025 at Club Volta for 28.35 EUR
# Parsing line: Booze & Glory on 14.11.2025 at Club Volta for 34.7 EUR
# Parsing line: The Young Gods on 17.11.2025 at Club Volta for 31.8 EUR
# Parsing line: Mother Tongue on 25.11.2025 at Club Volta for 33.6 EUR
# Parsing line: Rise Of The Northstar on 09.12.2025 at Club Volta for 44.5 EUR
# Parsing line: Deaf Havana on 29.01.2026 at Club Volta for 31.6 EUR
# Parsing line: Schmutzki on 12.03.2026 at Club Volta for 38.45 EUR
# Parsing line: We Came As Romans on 04.10.2025 at Essigfabrik for 47.9 EUR
# Parsing line: Nasty on 11.10.2025 at Essigfabrik for 37.0 EUR
# Parsing line: Jaill on 18.10.2025 at Essigfabrik for 39.4 EUR
# Parsing line: Curtis Harding on 04.11.2025 at Essigfabrik for 44.25 EUR
# Parsing line: Guilt Trip on 28.11.2025 at Essigfabrik for 33.75 EUR
# Parsing line: Chelsea Grin on 30.11.2025 at Essigfabrik for 43.35 EUR
# Parsing line: Of Mice And Men on 05.12.2025 at Essigfabrik for 42.4 EUR
# Parsing line: HGich.T on 16.01.2026 at Essigfabrik for 34.7 EUR
# Parsing line: Earl Sweatshirt on 08.02.2026 at Essigfabrik for 46.4 EUR
# Parsing line: Mobb Deep on 16.04.2026 at Essigfabrik for 44.0 EUR
# Parsing line: Oxo on 19.12.2025 at Essigfabrik for 86.0 EUR
# Parsing line: Lord Huron on 15.09.2025 at E-Werk for 43.5 EUR Ausverkauft!
# Parsing line: The Cat Empire on 06.10.2025 at E-Werk for 49.25 EUR
# Parsing line: Larkin Poe on 26.10.2025 at E-Werk for 55.75 EUR
# Parsing line: Skindred on 16.11.2025 at E-Werk for 44.65 EUR
# Parsing line: Big Thief on 14.04.2026 at E-Werk for 54.24 EUR
# Parsing line: Moneybrother on 13.09.2025 at Gebäude 9 for 38.2 EUR Ausverkauft!
# Parsing line: Richy Mitch & The Coal Miners on 14.09.2025 at Gebäude 9 for 32.75 EUR
# Parsing line: Ten56. on 18.09.2025 at Gebäude 9 for 31.6 EUR
# Parsing line: Poison The Well on 19.09.2025 at Gebäude 9 for 46.95 EUR Ausverkauft!
# Parsing line: Young Rebel Set on 20.09.2025 at Gebäude 9 for 37.2 EUR
# Parsing line: Darkest Hour on 26.09.2025 at Gebäude 9 for 40.85 EUR
# Parsing line: Malou Lovis on 29.09.2025 at Gebäude 9 for 29.0 EUR
# Parsing line: Shame on 30.09.2025 at Gebäude 9 for 35.9 EUR
# Parsing line: Zoot Woman on 02.10.2025 at Gebäude 9 for 35.9 EUR
# Parsing line: Duesenjaeger on 03.10.2025 at Gebäude 9 for 24.5 EUR
# Parsing line: Witch Club Satan on 05.10.2025 at Gebäude 9 for 26.96 EUR Ausverkauft!
# Parsing line: Sharktank on 07.10.2025 at Gebäude 9 for 34.9 EUR
# Parsing line: Sophia Kennedy on 08.10.2025 at Gebäude 9 for 26.4 EUR verlegt vom Bumann & Sohn (Popanz Show)
# Parsing line: Starsailor on 10.10.2025 at Gebäude 9 for 34.7 EUR Ausverkauft!
# Parsing line: Inspector Cluzo on 11.10.2025 at Gebäude 9 for 30.45 EUR
# Parsing line: bac on 15.10.2025 at Gebäude 9 for 30.0 EUR
# Parsing line: L.A. Salami on 16.10.2025 at Gebäude 9 for 27.5 EUR
# Parsing line: As December Falls on 17.10.2025 at Gebäude 9 for 30.7 EUR
# Parsing line: Orannsi Pazuzu on 18.10.2025 at Gebäude 9 for 30.37 EUR
# Parsing line: Joya Marleen on 20.10.2025 at Gebäude 9 for 26.0 EUR
# Parsing line: Herrenmagazin on 23.10.2025 at Gebäude 9 for 27.7 EUR Ausverkauft!
# Parsing line: Drei Meter Feldweg on 24.10.2025 at Gebäude 9 for 30.2 EUR
# Parsing line: Augn on 25.10.2025 at Gebäude 9 for 28.1 EUR
# Parsing line: Alarmsignal on 01.11.2025 at Gebäude 9 for 30.95 EUR
# Parsing line: Hotel Rimini on 02.11.2025 at Gebäude 9 for 27.5 EUR
# Parsing line: Roya on 03.11.2025 at Gebäude 9 for 33.9 EUR
# Parsing line: DYSE on 04.11.2025 at Gebäude 9 for 29.5 EUR
# Parsing line: Easy Easy on 05.11.2025 at Gebäude 9 for 25.9 EUR
# Parsing line: Foxwarren on 06.11.2025 at Gebäude 9 for 30.45 EUR
# Parsing line: Pogendroblem on 07.11.2025 at Gebäude 9 for 24.2 EUR
# Parsing line: Erik Cohen on 08.11.2025 at Gebäude 9 for 28.0 EUR
# Parsing line: Ghostwoman on 10.11.2025 at Gebäude 9 for 27.5 EUR
# Parsing line: King Hannah on 11.11.2025 at Gebäude 9 for 29.2 EUR
# Parsing line: McLusky on 13.11.2025 at Gebäude 9 for 27.5 EUR
# Parsing line: Cate Le Bon on 14.11.2025 at Gebäude 9 for 29.7 EUR
# Parsing line: Balthvs on 15.11.2025 at Gebäude 9 for 37.2 EUR
# Parsing line: Mono on 17.11.2025 at Gebäude 9 for 34.7 EUR
# Parsing line: Minami Deutsch on 18.11.2025 at Gebäude 9 for 26.4 EUR
# Parsing line: Van Holzen on 20.11.2025 at Gebäude 9 for 29.1 EUR
# Parsing line: Marathonmann on 21.11.2025 at Gebäude 9 for 29.8 EUR
# Parsing line: Matt Anderson on 23.11.2025 at Gebäude 9 for 34.7 EUR
# Parsing line: Frankie And The Witchfingers on 25.11.2025 at Gebäude 9 for 25.3 EUR
# Parsing line: Friso on 01.12.2025 at Gebäude 9 for 33.7 EUR
# Parsing line: Lambrini Girls on 07.12.2025 at Gebäude 9 for None EUR
# Parsing line: The Meteors on 09.12.2025 at Gebäude 9 for 31.95 EUR
# Parsing line: Iedereen on 11.12.2025 at Gebäude 9 for 24.2 EUR
# Parsing line: Extrabreit on 12.12.2025 at Gebäude 9 for 44.85 EUR
# Parsing line: KMPFSPRT on 13.12.2025 at Gebäude 9 for 24.2 EUR
# Parsing line: Loathe on 14.12.2025 at Gebäude 9 for 37.3 EUR
# Parsing line: Bernd Begemann on 27.12.2025 at Gebäude 9 for 22.0 EUR
# Parsing line: Born Of Osiris on 09.01.2026 at Gebäude 9 for 42.95 EUR
# Parsing line: Demented Are Go on 10.01.2026 at Gebäude 9 for 32.95 EUR
# Parsing line: Pabst on 23.01.2026 at Gebäude 9 for 27.5 EUR
# Parsing line: Nanowar Of Steel on 29.01.2026 at Gebäude 9 for 40.7 EUR
# Parsing line: Kontrollverlust on 31.01.2026 at Gebäude 9 for 32.4 EUR
# Parsing line: Anna Von Hausswolff on 04.02.2026 at Gebäude 9 for 32.75 EUR
# Parsing line: Arms Lenght on 20.02.2026 at Gebäude 9 for 33.35 EUR
# Parsing line: Elwood Stray & Our Mirage on 21.02.2026 at Gebäude 9 for 28.95 EUR
# Parsing line: Rosmarin on 22.02.2026 at Gebäude 9 for 30.7 EUR
# Parsing line: A.A. Williams on 26.02.2026 at Gebäude 9 for 29.0 EUR
# Parsing line: Good Neighbours on 03.03.2026 at Gebäude 9 for 33.9 EUR
# Parsing line: Kafvka on 13.03.2026 at Gebäude 9 for 31.3 EUR
# Parsing line: Spidergawd on 17.03.2026 at Gebäude 9 for 41.5 EUR
# Parsing line: Kapa Tult on 18.03.2026 at Gebäude 9 for 27.5 EUR
# Parsing line: Doctor Krapula on 27.03.2026 at Gebäude 9 for 26.4 EUR
# Parsing line: Full Of Hell, The Body on 04.04.2026 at Gebäude 9 for 33.77 EUR
# Parsing line: Lansdowne on 16.04.2026 at Gebäude 9 for 29.1 EUR
# Parsing line: The Toten Crackhuren im Kofferraum on 17.04.2026 at Gebäude 9 for 33.5 EUR
# Parsing line: Hundreds on 21.04.2026 at Gebäude 9 for 42.75 EUR
# Parsing line: Salò on 07.05.2026 at Gebäude 9 for 33.8 EUR
# Parsing line: Hardline on 08.05.2026 at Gebäude 9 for 41.5 EUR
# Parsing line: Rami Hattab on 30.05.2026 at Gebäude 9 for 34.7 EUR
# Parsing line: Hooverphonic on 06.10.2025 at Gloria for 51.7 EUR
# Parsing line: Black Country, New Road on 14.10.2025 at Gloria for 35.2 EUR
# Parsing line: Beach Bunny on 15.10.2025 at Gloria for 33.5 EUR
# Parsing line: Die Höchste Eisenbahn on 01.12.2025 at Gloria for 42.2 EUR Ausverkauft!
# Parsing line: Erdmöbel on 22.12.2025 at Gloria for 35.1 EUR
# Parsing line: Yin Yin on 05.03.2026 at Gloria for 29.8 EUR
# Parsing line: Black Sea Dahu on 01.04.2026 at Gloria for 41.85 EUR
# Parsing line: Milliarden on 02.04.2026 at Gloria for 39.9 EUR
# Parsing line: Herrenmagazin on 10.12.2025 at Gloria for 41.05 EUR
# Parsing line: Caleb Hearn on 23.09.2025 at Helios 37 for 29.3 EUR
# Parsing line: Blondshell on 25.09.2025 at Helios 37 for 30.3 EUR Ausverkauft!
# Parsing line: Rachel Grae on 01.10.2025 at Helios 37 for 23.55 EUR
# Parsing line: Ritual on 02.10.2025 at Helios 37 for 22.5 EUR
# Parsing line: Hellsongs on 09.10.2025 at Helios 37 for 25.9 EUR
# Parsing line: Tim Vantol on 11.10.2025 at Helios 37 for 35.7 EUR
# Parsing line: Catapults on 16.10.2025 at Helios 37 for 23.7 EUR
# Parsing line: The Vices on 26.10.2025 at Helios 37 for 27.6 EUR
# Parsing line: Greyscale on 09.11.2025 at Helios 37 for 30.55 EUR
# Parsing line: Softcult on 18.11.2025 at Helios 37 for 25.85 EUR
# Parsing line: Swim School on 22.11.2025 at Helios 37 for 28.15 EUR
# Parsing line: Pudeldame on 25.11.2025 at Helios 37 for 28.1 EUR
# Parsing line: Sparkling on 28.11.2025 at Helios 37 for 22.0 EUR
# Parsing line: Slow Crush on 30.11.2025 at Helios 37 for 30.7 EUR
# Parsing line: Saturdays at your place on 18.01.2026 at Helios 37 for 25.0 EUR
# Parsing line: Still Talk on 24.01.2026 at Helios 37 for 25.9 EUR
# Parsing line: Eläkeläiset on 20.04.2026 at Helios 37 for 30.3 EUR
# Parsing line: Hohnen Ford on 05.10.2025 at Jaki for 29.15 EUR
# Parsing line: Ende on 15.10.2025 at Jaki for 23.7 EUR
# Parsing line: Afar on 24.10.2025 at Jaki for 22.0 EUR
# Parsing line: Ethan Regan on 07.12.2025 at Jaki for 28.15 EUR
# Parsing line: David Bay on 08.12.2025 at Jaki for 23.7 EUR
# Parsing line: Dope Lemon on 15.09.2025 at Kantine for 47.8 EUR
# Parsing line: Umse on 27.09.2025 at Kantine for 34.7 EUR
# Parsing line: Siena Root on 02.10.2025 at Kantine for 27.0 EUR
# Parsing line: The Beths on 03.10.2025 at Kantine for 27.5 EUR
# Parsing line: The Pharcyde on 16.10.2025 at Kantine for 55.1 EUR
# Parsing line: Anda Morts on 28.10.2025 at Kantine for 30.3 EUR
# Parsing line: Everything Everything on 03.11.2025 at Kantine for 36.2 EUR
# Parsing line: Gorilla Biscuits, Terror, No Pressure on 17.11.2025 at Kantine for 41.5 EUR
# Parsing line: Baxter Dury on 27.11.2025 at Kantine for 44.65 EUR
# Parsing line: Lambrini Girls on 07.12.2025 at Kantine for 27.5 EUR
# Parsing line: Slime on 23.01.2026 at Kantine for 44.9 EUR
# Parsing line: Tortoise on 27.01.2026 at Kantine for 42.4 EUR
# Parsing line: Blossoms on 10.02.2026 at Kantine for 33.9 EUR
# Parsing line: Sprints on 14.03.2026 at Kantine for 33.9 EUR
# Parsing line: Geese on 18.03.2026 at Kantine for 30.45 EUR
# Parsing line: Godspeed You! Black Emperor on 20.03.2026 at Kantine for 41.87 EUR
# Parsing line: She Past Away on 08.05.2026 at Kantine for 40.77 EUR
# Parsing line: Bonaparte on 29.10.2025 at Kantine for 47.25 EUR
# Parsing line: Betterov on 15.10.2025 at Kulturkirche for 44.5 EUR Ausverkauft!
# Parsing line: Jadu Heart on 04.11.2025 at Kulturkirche for 37.2 EUR
# Parsing line: Becky Sikasa on 07.11.2025 at Kulturkirche for 27.5 EUR
# Parsing line: Steiner & Madlaina on 11.11.2025 at Kulturkirche for 44.5 EUR
# Parsing line: Cara Rose on 13.11.2025 at Kulturkirche for 29.2 EUR
# Parsing line: Fil Bo Riva on 19.11.2025 at Kulturkirche for 47.25 EUR
# Parsing line: Fortuna Ehrenfeld on 09.12.2025 at Kulturkirche for 44.63 EUR
# Parsing line: Fortuna Ehrenfeld on 10.12.2025 at Kulturkirche for 44.63 EUR
# Parsing line: Bob Dylan on 03.11.2025 at Lanxess Arena for 70.0 EUR
# Parsing line: Nina Chuba on 06.11.2025 at Lanxess Arena for 52.9 EUR Ausverkauft!
# Parsing line: Gogol Bordello on 13.09.2025 at Live Music Hall for 46.95 EUR
# Parsing line: Mogwai on 20.09.2025 at Live Music Hall for 50.32 EUR
# Parsing line: Basement on 26.09.2025 at Live Music Hall for 35.9 EUR
# Parsing line: The Midnight on 28.09.2025 at Live Music Hall for 43.5 EUR Ausverkauft!
# Parsing line: Igorrr on 12.10.2025 at Live Music Hall for 44.5 EUR
# Parsing line: Atreyu on 18.10.2025 at Live Music Hall for 46.95 EUR
# Parsing line: Banks on 20.10.2025 at Live Music Hall for 47.0 EUR
# Parsing line: Paradise Lost on 23.10.2025 at Live Music Hall for 49.25 EUR
# Parsing line: Jonny Maar on 26.10.2025 at Live Music Hall for 45.05 EUR
# Parsing line: Kadavar on 28.10.2025 at Live Music Hall for 44.5 EUR
# Parsing line: The Darkness on 30.10.2025 at Live Music Hall for 44.65 EUR
# Parsing line: Arrested Development on 02.11.2025 at Live Music Hall for 55.0 EUR
# Parsing line: Kae Tempest on 03.11.2025 at Live Music Hall for 49.28 EUR
# Parsing line: Malevolence on 05.11.2025 at Live Music Hall for 47.0 EUR
# Parsing line: John Butler on 08.11.2025 at Live Music Hall for 45.0 EUR
# Parsing line: Noga Erez on 23.11.2025 at Live Music Hall for 45.0 EUR
# Parsing line: Joy Crookes on 29.11.2025 at Live Music Hall for 41.8 EUR
# Parsing line: Clutch on 10.12.2025 at Live Music Hall for 43.5 EUR
# Parsing line: Counterparts on 05.02.2026 at Live Music Hall for 44.4 EUR
# Parsing line: White Lies on 24.02.2026 at Live Music Hall for 46.95 EUR
# Parsing line: La Dispute on 10.03.2026 at Live Music Hall for 35.05 EUR
# Parsing line: Prinz Pi on 11.10.2025 at Live Music Hall for 52.79 EUR
# Parsing line: Nova Twins on 21.09.2025 at Luxor for 28.15 EUR
# Parsing line: Billie Marten on 02.11.2025 at Luxor for 30.45 EUR
# Parsing line: Flipturn on 04.11.2025 at Luxor for 30.45 EUR
# Parsing line: Destroyer + The Weather Station on 08.11.2025 at Luxor for 34.7 EUR
# Parsing line: Skinny Lister on 29.11.2025 at Luxor for 32.75 EUR
# Parsing line: Deaf Havana on 23.01.2026 at Luxor for 30.45 EUR Ausverkauft!
# Parsing line: Teenage Dads on 17.09.2025 at MTC for 28.15 EUR
# Parsing line: L.A. Witch on 30.09.2025 at MTC for 30.45 EUR
# Parsing line: Big Special on 28.10.2025 at MTC for 32.6 EUR Ausverkauft!
# Parsing line: Triggerfinger on 12.11.2025 at MTC for 32.5 EUR
# Parsing line: Sons on 22.11.2025 at MTC for 27.0 EUR
# Parsing line: Florence Black on 26.11.2025 at MTC for 30.6 EUR
# Parsing line: The Scratch on 27.11.2025 at MTC for 30.45 EUR
# Parsing line: Deviloof on 02.12.2025 at MTC for 47.65 EUR
# Parsing line: Militarie Gun on 30.01.2026 at MTC for 30.45 EUR
# Parsing line: The Aces on 11.02.2026 at MTC for 31.6 EUR
# Parsing line: Tulpe on 21.02.2026 at MTC for 29.4 EUR
# Parsing line: Coach Party on 28.02.2026 at MTC for 27.0 EUR
# Parsing line: Indie Cologne Fest on 21.09.2025 at MTC for 17.6 EUR
# Parsing line: Little Simz on 29.09.2025 at Palladium for 56.75 EUR Ausverkauft!
# Parsing line: Meute on 02.10.2025 at Palladium for 59.35 EUR
# Parsing line: Loyle Carner on 22.10.2025 at Palladium for 68.25 EUR
# Parsing line: OG Keemo on 25.10.2025 at Palladium for 44.49 EUR Ausverkauft!
# Parsing line: Von Wegen Lisbeth on 01.11.2025 at Palladium for 48.0 EUR
# Parsing line: H-Blockx on 02.11.2025 at Palladium for 58.7 EUR
# Parsing line: Dropkick Murphys on 03.11.2025 at Palladium for 67.9 EUR
# Parsing line: Dropkick Murphys on 04.11.2025 at Palladium for 67.9 EUR
# Parsing line: Wolf Alice on 17.11.2025 at Palladium for 45.25 EUR
# Parsing line: Blond on 18.11.2025 at Palladium for 47.4 EUR
# Parsing line: Killwitch Engage on 20.11.2025 at Palladium for 59.0 EUR
# Parsing line: Mine on 25.11.2025 at Palladium for 61.9 EUR
# Parsing line: The Hives on 01.12.2025 at Palladium for 57.55 EUR
# Parsing line: Royal Otis on 08.12.2025 at Palladium for 47.0 EUR
# Parsing line: Landmvrks on 19.12.2025 at Palladium for 56.45 EUR
# Parsing line: Jinjer on 23.01.2026 at Palladium for 51.25 EUR
# Parsing line: Heaven Shall Burn on 28.02.2026 at Palladium for 69.4 EUR
# Parsing line: Franz Ferdinand on 04.04.2026 at Palladium for 62.5 EUR
# Parsing line: Kaffkiez on 12.04.2026 at Palladium for 54.4 EUR
# Parsing line: Sportfreunde Stiller on 11.05.2026 at Palladium for 53.85 EUR
# Parsing line: Fortuna Ehrenfeld on 22.10.2025 at Philharmonie for 28.5 EUR
# Parsing line: Fortuna Ehrenfeld on 23.10.2025 at Philharmonie for 28.5 EUR Ausverkauft!
# Parsing line: Toxoplasma on 12.09.2026 at Sonic Ballroom for 16.5 EUR Ausverkauft!
# Parsing line: The Slapstickers on 13.09.2025 at Sonic Ballroom for 17.6 EUR
# Parsing line: Lord Rochester on 16.09.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Popperklopper on 19.09.2025 at Sonic Ballroom for 14.3 EUR
# Parsing line: The Vovos on 20.09.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: Violencia on 24.09.2025 at Sonic Ballroom for 14.3 EUR
# Parsing line: Guts Pie Earshot on 25.09.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: Bratakus on 26.09.2025 at Sonic Ballroom for 14.3 EUR
# Parsing line: The Tips on 02.10.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: Hamburger Spinners on 04.10.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Negative Blast on 08.10.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: Karaoke Till Death on 09.10.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Karaoke Till Death on 10.10.2025 at Sonic Ballroom for 16.5 EUR Ausverkauft!
# Parsing line: The Backyard Band on 18.10.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: The Quakes on 29.10.2025 at Sonic Ballroom for 17.6 EUR
# Parsing line: Banana Peel Slippers on 01.11.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Bazooka Zirkus on 07.11.2025 at Sonic Ballroom for 14.3 EUR
# Parsing line: The Turbo A.C.s on 13.11.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Der Dumme August on 14.11.2025 at Sonic Ballroom for 14.3 EUR
# Parsing line: The Darts on 18.11.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Sedlmeir on 20.11.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: Karoshi on 21.11.2025 at Sonic Ballroom for 15.4 EUR
# Parsing line: The Schizophonics on 22.11.2025 at Sonic Ballroom for 17.6 EUR
# Parsing line: Long Tall Texans on 26.11.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Nichts on 05.12.2025 at Sonic Ballroom for 16.5 EUR
# Parsing line: Jesper Munk on 15.10.2025 at Stadtgarten for 31.4 EUR
# Parsing line: The Rural Alberta Advantage on 10.12.2025 at Stadtgarten for 35.0 EUR
# Parsing line: Grandbrothers on 01.11.2025 at Stadthalle Köln for 41.6 EUR
# Parsing line: Erobique on 30.12.2025 at Stadthalle Köln for 42.2 EUR
# Parsing line: Divine Comedy on 15.03.2026 at Stadthalle Köln for 53.9 EUR Ausverkauft!
# Parsing line: Belle & Sebastian performing Tigermilk on 17.03.2026 at Stadthalle Köln for 55.0 EUR
# Parsing line: Belle & Sebastian performing If You’re Feeling Sinister on 18.03.2026 at Stadthalle Köln for 55.0 EUR
# Parsing line: JNSN on 27.09.2025 at Stereo Wonderland for 21.0 EUR
# Parsing line: Sick Fizz on 09.10.2025 at Stereo Wonderland for 17.88 EUR
# Parsing line: Snake Eyes on 15.10.2025 at Stereo Wonderland for 18.0 EUR
# Parsing line: Grillmaster Flash on 23.10.2025 at Stereo Wonderland for 20.0 EUR
# Parsing line: Drangsal on 27.09.2025 at Stollwerck for 41.75 EUR
# Parsing line: K’s Choice on 08.10.2025 at Stollwerck for 52.95 EUR
# Parsing line: Refused on 10.10.2025 at Stollwerck for 49.45 EUR Ausverkauft!
# Parsing line: Coheed And Cambria on 11.10.2025 at Stollwerck for 44.5 EUR Ausverkauft!
# Parsing line: Mantar on 24.10.2025 at Stollwerck for 34.7 EUR
# Parsing line: The Subways on 24.11.2025 at Stollwerck for 40.05 EUR
# Parsing line: Deus on 24.03.2026 at Stollwerck for 51.0 EUR
# Parsing line: Nickless on 29.10.2025 at Subway for 29.1 EUR
# Parsing line: Neon Dreams on 12.11.2025 at Subway for 25.9 EUR
# Parsing line: Donots on 19.09.2025 at Südbrücke for 52.75 EUR
# Parsing line: Antilopden Gang on 20.09.2025 at Südbrücke for 53.05 EUR
# Parsing line: Soap & Skin on 17.10.2025 at Tanzbrunnen for 49.45 EUR
# Parsing line: RedHook on 10.05.2026 at Tsunami Club for 25.8 EUR
# Parsing line: Bulgarian Cartrader on 07.10.2025 at Tsunami Club for 28.0 EUR
# Parsing line: Mar Malade on 03.10.2025 at Wohngemeinschaft for 23.7 EUR Ausverkauft!
# Parsing line: Bertie Newman on 26.11.2025 at Wohngemeinschaft for 25.9 EUR
# Parsing line: Chloe Moriondo on 15.09.2025 at Yuca for 30.45 EUR
# Parsing line: Sofie Royer on 22.09.2025 at Yuca for 25.9 EUR
# Parsing line: Kings Elliot on 11.10.2025 at Yuca for 33.3 EUR
# Parsing line: Great Grandpa on 05.11.2025 at Yuca for 30.45 EUR
# Parsing line: Panic Shack on 22.11.2025 at Yuca for 30.3 EUR
# Parsing line: Jerub on 28.11.2025 at Yuca for 33.9 EUR
# Parsing line: Big Sleep on 02.12.2025 at Yuca for 28.15 EUR
# Parsing line: Noso on 10.02.2026 at Yuca for 24.7 EUR
# [{'date': datetime.datetime(2025, 9, 13, 0, 0),
#   'band': 'Moneybrother',
#   'location': 'Gebäude 9',
#   'price': 38.2,
#   'status': 'Ausverkauft!'},
#  {'date': datetime.datetime(2025, 9, 13, 0, 0),
#   'band': 'Gogol Bordello',
#   'location': 'Live Music Hall',
#   'price': 46.95,
#   'status': ''},
#  {'date': datetime.datetime(2025, 9, 13, 0, 0),
#   'band': 'The Slapstickers',
#   'location': 'Sonic Ballroom',
#   'price': 17.6,
#   'status': ''},
#  {'date': datetime.datetime(2025, 9, 14, 0, 0),
#   'band': 'Greg Freeman',
#   'location': 'Blue Shell',
#   'price': 29.3,
#   'status': ''},
#  {'date': datetime.datetime(2025, 9, 14, 0, 0),
#   'band': 'Richy Mitch & The Coal Miners',
#   'location': 'Gebäude 9',
#   'price': 32.75,
#   'status': ''}]

# %%
import re
import requests
from bs4 import BeautifulSoup
from datetime import datetime

URL = "https://underdogrecordstore.de/vorverkauf"

# ---------- utilities ----------

def get_lines_from_page(url: str):
    r = requests.get(url, timeout=20)
    r.raise_for_status()
    soup = BeautifulSoup(r.text, "html.parser")
    text = soup.get_text("\n", strip=True)          # robust split into lines
    return [ln.strip() for ln in text.splitlines() if ln.strip()]

def fetch_locations_from_headings(lines):
    """Section headings (end with ':') become known locations."""
    return [ln[:-1].strip() for ln in lines if ln.endswith(":")]

def build_event_pattern():
    """
    Base event regex that:
    - captures date, band, optional @location, optional price
    - uses lookaheads so band/location stop before price/status/paren/EOL
    - captures the full trailing status text into 'status_text'
    """
    return re.compile(
        r"""
        ^\s*
        (?P<date>\d{2}\.\d{2}\.)\s+                 # DD.MM.
        (?P<band>.+?)                               # band (lazy)
        (?=                                         # band boundary
            (?:\s+@\s|                              # '@ location' ahead
               \s+[*]?(?:ab\s*)?\d+(?:[.,]\d{1,2})?\s*€? |  # or price
               \s*(?:$|\(|Ausverkauft|Verlegt)      # or EOL/paren/status
            )
        )
        (?:\s+@\s*
            (?P<location>.+?)                       # @ location (digits allowed)
            (?=                                     # location boundary
               (?:\s+[*]?(?:ab\s*)?\d+(?:[.,]\d{1,2})?\s*€? |
                  \s*(?:$|\(|Ausverkauft|Verlegt)
               )
            )
        )?
        (?:\s+[*]?(?:ab\s*)?
            (?P<price>\d+(?:[.,]\d{1,2})?)\s*€?     # optional price
        )?
        (?:\s*(?P<status_text>(?:Ausverkauft!?|[Vv]erlegt)[^\n]*))?  # full status text
        """,
        re.VERBOSE | re.UNICODE
    )

# status helpers
ARTICLES = r"(?:die|den|das|dem|der)\s+"
PREPS    = r"(?:in|nach|vom|von)\s+"      # most common forms

STATUS_PATTERNS = [
    (re.compile(r"\bausverkauft!?$", re.I), "ausverkauft"),
    (re.compile(r"\babgesagt!?$", re.I), "abgesagt"),
    (re.compile(r"\bverlegt\b.*", re.I), "verlegt"),
]

def parse_status(line: str, known_locs):
    """
    Extract (status_kind, new_location, status_raw) from the line.
    """
    status_kind, new_location, status_raw = "", "", ""

    for pat, kind in STATUS_PATTERNS:
        m = pat.search(line)
        if not m:
            continue
        status_kind = kind
        status_raw = m.group(0).strip()
        break

    # if verlegt → try to detect target location
    if status_kind == "verlegt":
        s = status_raw
        for loc in sorted(known_locs, key=len, reverse=True):
            if re.search(rf"\b{re.escape(loc)}\b", s, flags=re.I):
                new_location = loc
                break
        if not new_location:
            mm = re.search(r"(?:in|nach|vom|von\s+(?:die|den|das|dem|der))?\s*(?P<loc>[^,(]+)", s, re.I)
            if mm:
                new_location = mm.group("loc").strip()

    return status_kind, new_location, status_raw

# ---------- main ----------

def fetch_events():
    lines = get_lines_from_page(URL)
    known_locations = fetch_locations_from_headings(lines)
    event_re = build_event_pattern()

    now = datetime.now()
    events = []
    section = None

    for line in lines:
        if line.endswith(":"):
            section = line[:-1].strip()
            continue

        m = event_re.match(line)
        if not m:
            continue

        gd = m.groupdict()
        date = gd["date"]
        band = (gd["band"] or "").strip()
        at_loc = (gd.get("location") or "").strip()
        price_raw = gd.get("price")
        status_text = gd.get("status_text") or ""

        # prefer explicit @location; else section heading
        location = at_loc if at_loc else (section or "")

        # date → with year; roll over if already past this year
        d = datetime.strptime(date + str(now.year), "%d.%m.%Y")
        if d.date() < now.date():
            d = d.replace(year=now.year + 1)

        # price normalize
        price_eur = float(price_raw.replace(",", ".")) if price_raw else None

        # structured status
        status_kind, new_location, status_raw = parse_status(line, known_locations)

        events.append({
            "origin": line,
            "date": d,
            "band": band,
            "location": location,
            "price_eur": price_eur,
            "status_kind": status_kind,     # 'ausverkauft' | 'verlegt' | 'abgesagt' | ''
            "new_location": new_location,   # Ziel-Location falls 'verlegt'
            "status_raw": status_raw,       # original status string
            "section": section,
        })

    events.sort(key=lambda x: x["date"])
    return events

events = fetch_events()

# %%
import pandas as pd
from datetime import datetime

def save_events_csv(events, basepath="events"):
    """
    Save events to a timestamped JSON file.
    - basepath: without extension, e.g. 'events' → events_YYYYMMDD_HHMMSS.csv
    """
    df = pd.DataFrame(events)

    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    json_path = f"{basepath}_{ts}.json"

    # add id column starting from 1
    df.insert(0, "id", range(1, len(df) + 1))

    # pretty print to JSON, no records orientation
    df.to_json(json_path, index=False, indent=4, date_format="iso", force_ascii=False, orient="records")

    print(f"✅ Saved {len(df)} events to {json_path}")
    return json_path

json_file = save_events_csv(events, basepath="concert_events")
# Out:
# ✅ Saved 374 events to concert_events_20250919_005906.json

# %%
import os
import glob
import pandas as pd

def load_latest_events(basepath="concert_events"):
    """
    Find the latest JSON file saved by save_events_csv() and return a list of dicts.
    """
    pattern = f"{basepath}_*.json"
    files = glob.glob(pattern)
    if not files:
        raise FileNotFoundError(f"No files found matching {pattern}")

    latest_file = max(files, key=os.path.getmtime)

    df = pd.read_json(latest_file)
    # Replace NaN with None
    #df = df.where(pd.notnull(df), None)
    
    events = df.to_dict(orient="records")

    print(f"✅ Loaded {len(events)} events from {latest_file}")
    return events

loaded_events = load_latest_events("concert_events")
# Out:
# ✅ Loaded 374 events from concert_events_20250919_005633.json

# %%
from IPython.display import HTML

for e in loaded_events:
    print(f"\n")
    print(f"Origin: {e['origin']}")
    print(f"{e['date'].date()} — {e['band']} — {e['location']} — {e['price_eur']} €")
    print(f"   Status: {e['status_kind']} {e['new_location']}")
    print(f"   Raw: {e['status_raw']}")
    # print(f"   Genres: {e['genres']}")
    # print(f"   Spotify: {e['spotify_link']}")
# Out:
# Origin: 19.09. Poison The Well 46,95 € Ausverkauft!
# 2025-09-19 — Poison The Well — Gebäude 9 — 46.95 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 19.09. Popperklopper *14,30 €
# 2025-09-19 — Popperklopper — Sonic Ballroom — 14.3 €
#    Status:
#    Raw:
#
#
# Origin: 19.09. Donots 52,75 €
# 2025-09-19 — Donots — Südbrücke — 52.75 €
#    Status:
#    Raw:
#
#
# Origin: 20.09. Müllem Mon Amour 46,20 € (Hardtickets) Abgesagt!
# 2025-09-20 — Müllem Mon Amour — Carlswerk Victoria — 46.2 €
#    Status: abgesagt
#    Raw: Abgesagt!
#
#
# Origin: 20.09. Young Rebel Set 37,20
# 2025-09-20 — Young Rebel Set — Gebäude 9 — 37.2 €
#    Status:
#    Raw:
#
#
# Origin: 20.09. Mogwai 50,32 €
# 2025-09-20 — Mogwai — Live Music Hall — 50.32 €
#    Status:
#    Raw:
#
#
# Origin: 20.09. The Vovos *15,40 €
# 2025-09-20 — The Vovos — Sonic Ballroom — 15.4 €
#    Status:
#    Raw:
#
#
# Origin: 20.09. Antilopden Gang 53,05 €
# 2025-09-20 — Antilopden Gang — Südbrücke — 53.05 €
#    Status:
#    Raw:
#
#
# Origin: 21.09. Nova Twins 28,15 €
# 2025-09-21 — Nova Twins — Luxor — 28.15 €
#    Status:
#    Raw:
#
#
# Origin: 21.09. Indie Cologne Fest 17,60 € (Hardtickets)
# 2025-09-21 — Indie Cologne Fest — MTC — 17.6 €
#    Status:
#    Raw:
#
#
# Origin: 22.09. Boyish 24,70 €
# 2025-09-22 — Boyish — Blue Shell — 24.7 €
#    Status:
#    Raw:
#
#
# Origin: 22.09. Sofie Royer 25,90 €
# 2025-09-22 — Sofie Royer — Yuca — 25.9 €
#    Status:
#    Raw:
#
#
# Origin: 23.09. Preoccupations 28,10 €
# 2025-09-23 — Preoccupations — Blue Shell — 28.1 €
#    Status:
#    Raw:
#
#
# Origin: 23.09. Sababa 5 *22 € (Popanz Show)
# 2025-09-23 — Sababa — Bumann & Sohn — 5.0 €
#    Status:
#    Raw:
#
#
# Origin: 23.09. Caleb Hearn 29,30 €
# 2025-09-23 — Caleb Hearn — Helios 37 — 29.3 €
#    Status:
#    Raw:
#
#
# Origin: 24.09. Ozan Ata Canani & Die Demokratie *19,80 € (Popanz Show)
# 2025-09-24 — Ozan Ata Canani & Die Demokratie — Bumann & Sohn — 19.8 €
#    Status:
#    Raw:
#
#
# Origin: 24.09. Violencia *14,30 €
# 2025-09-24 — Violencia — Sonic Ballroom — 14.3 €
#    Status:
#    Raw:
#
#
# Origin: 25.09. Blondshell 30,30 € Ausverkauft!
# 2025-09-25 — Blondshell — Helios 37 — 30.3 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 25.09. Guts Pie Earshot *15,40 €
# 2025-09-25 — Guts Pie Earshot — Sonic Ballroom — 15.4 €
#    Status:
#    Raw:
#
#
# Origin: 26.09. EivØr 60,90 €
# 2025-09-26 — EivØr — Carlswerk Victoria — 60.9 €
#    Status:
#    Raw:
#
#
# Origin: 26.09. Better Lovers 32,75 €
# 2025-09-26 — Better Lovers — Club Volta — 32.75 €
#    Status:
#    Raw:
#
#
# Origin: 26.09. Darkest Hour 40,85 €
# 2025-09-26 — Darkest Hour — Gebäude 9 — 40.85 €
#    Status:
#    Raw:
#
#
# Origin: 26.09. Basement 35,90 €
# 2025-09-26 — Basement — Live Music Hall — 35.9 €
#    Status:
#    Raw:
#
#
# Origin: 26.09. Bratakus *14,30 €
# 2025-09-26 — Bratakus — Sonic Ballroom — 14.3 €
#    Status:
#    Raw:
#
#
# Origin: 27.09. Umse 34,70 €
# 2025-09-27 — Umse — Kantine — 34.7 €
#    Status:
#    Raw:
#
#
# Origin: 27.09. JNSN 21 €
# 2025-09-27 — JNSN — Stereo Wonderland — 21.0 €
#    Status:
#    Raw:
#
#
# Origin: 27.09. Drangsal 41,75 €
# 2025-09-27 — Drangsal — Stollwerck — 41.75 €
#    Status:
#    Raw:
#
#
# Origin: 28.09. The Midnight 43,50 € Ausverkauft!
# 2025-09-28 — The Midnight — Live Music Hall — 43.5 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 29.09. Malou Lovis 29 €
# 2025-09-29 — Malou Lovis — Gebäude 9 — 29.0 €
#    Status:
#    Raw:
#
#
# Origin: 29.09. Little Simz 56,75 € Ausverkauft!
# 2025-09-29 — Little Simz — Palladium — 56.75 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 30.09. Jeffrey Lewis 26,96 €
# 2025-09-30 — Jeffrey Lewis — Club Volta — 26.96 €
#    Status:
#    Raw:
#
#
# Origin: 30.09. Shame 35,90 €
# 2025-09-30 — Shame — Gebäude 9 — 35.9 €
#    Status:
#    Raw:
#
#
# Origin: 30.09. L.A. Witch 30,45 €
# 2025-09-30 — L.A. Witch — MTC — 30.45 €
#    Status:
#    Raw:
#
#
# Origin: 01.10. Rachel Grae 23,55 €
# 2025-10-01 — Rachel Grae — Helios 37 — 23.55 €
#    Status:
#    Raw:
#
#
# Origin: 02.10. Ritual @ Helios 37 22,50 € (Hardtickets)
# 2025-10-02 — Ritual — Helios — 37.0 €
#    Status:
#    Raw:
#
#
# Origin: 02.10. Masters Of Reality 38,45 €
# 2025-10-02 — Masters Of Reality — Artheater — 38.45 €
#    Status:
#    Raw:
#
#
# Origin: 02.10. Zoot Woman 35,90 €
# 2025-10-02 — Zoot Woman — Gebäude 9 — 35.9 €
#    Status:
#    Raw:
#
#
# Origin: 02.10. Ritual 22,50 € (Hardtickets)
# 2025-10-02 — Ritual — Helios 37 — 22.5 €
#    Status:
#    Raw:
#
#
# Origin: 02.10. Siena Root 27 € (Yard Club)
# 2025-10-02 — Siena Root — Kantine — 27.0 €
#    Status:
#    Raw:
#
#
# Origin: 02.10. Meute 59,35 €
# 2025-10-02 — Meute — Palladium — 59.35 €
#    Status:
#    Raw:
#
#
# Origin: 02.10. The Tips *15,40 €
# 2025-10-02 — The Tips — Sonic Ballroom — 15.4 €
#    Status:
#    Raw:
#
#
# Origin: 03.10. Duesenjaeger @ Gebäude 9 24,50 € (Hardtickets)
# 2025-10-03 — Duesenjaeger — Gebäude — 9.0 €
#    Status:
#    Raw:
#
#
# Origin: 03.10. Those Damn Crows 32,75 € Ausverkauft!
# 2025-10-03 — Those Damn Crows — Club Bahnhof Ehrenfeld — 32.75 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 03.10. The Vintage Caravan 32,50 €
# 2025-10-03 — The Vintage Caravan — Club Volta — 32.5 €
#    Status:
#    Raw:
#
#
# Origin: 03.10. Duesenjaeger 24,50 € (Hardtickets)
# 2025-10-03 — Duesenjaeger — Gebäude 9 — 24.5 €
#    Status:
#    Raw:
#
#
# Origin: 03.10. The Beths *27,50 (Popanz Show)
# 2025-10-03 — The Beths — Kantine — 27.5 €
#    Status:
#    Raw:
#
#
# Origin: 03.10. Mar Malade 23,70 € Ausverkauft!
# 2025-10-03 — Mar Malade — Wohngemeinschaft — 23.7 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 04.10. We Came As Romans 47,90 €
# 2025-10-04 — We Came As Romans — Essigfabrik — 47.9 €
#    Status:
#    Raw:
#
#
# Origin: 04.10. Hamburger Spinners *16,50 €
# 2025-10-04 — Hamburger Spinners — Sonic Ballroom — 16.5 €
#    Status:
#    Raw:
#
#
# Origin: 05.10. Witch Club Satan 26,96 € Ausverkauft!
# 2025-10-05 — Witch Club Satan — Gebäude 9 — 26.96 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 05.10. Hohnen Ford 29,15 €
# 2025-10-05 — Hohnen Ford — Jaki — 29.15 €
#    Status:
#    Raw:
#
#
# Origin: 06.10. The Cat Empire 49,25 €
# 2025-10-06 — The Cat Empire — E-Werk — 49.25 €
#    Status:
#    Raw:
#
#
# Origin: 06.10. Hooverphonic 51,70 €
# 2025-10-06 — Hooverphonic — Gloria — 51.7 €
#    Status:
#    Raw:
#
#
# Origin: 07.10. Bulgarian Cartrader 28 €
# 2025-10-07 — Bulgarian Cartrader — Artheater — 28.0 €
#    Status:
#    Raw:
#
#
# Origin: 07.10. TV Cult *19,80 € (Popanz Show)
# 2025-10-07 — TV Cult — Bumann & Sohn — 19.8 €
#    Status:
#    Raw:
#
#
# Origin: 07.10. Sharktank 34,90 €
# 2025-10-07 — Sharktank — Gebäude 9 — 34.9 €
#    Status:
#    Raw:
#
#
# Origin: 07.10. Bulgarian Cartrader 28 €
# 2025-10-07 — Bulgarian Cartrader — Tsunami Club — 28.0 €
#    Status:
#    Raw:
#
#
# Origin: 08.10. Sophia Kennedy *26,40 € verlegt in das Gebäude 9 (Popanz Show)
# 2025-10-08 — Sophia Kennedy — Bumann & Sohn — 26.4 €
#    Status: verlegt Gebäude 9
#    Raw: verlegt in das Gebäude 9 (Popanz Show)
#
#
# Origin: 08.10. Sophia Kennedy *26,40 € verlegt vom Bumann & Sohn (Popanz Show)
# 2025-10-08 — Sophia Kennedy — Gebäude 9 — 26.4 €
#    Status: verlegt Bumann & Sohn
#    Raw: verlegt vom Bumann & Sohn (Popanz Show)
#
#
# Origin: 08.10. Negative Blast *15,40 €
# 2025-10-08 — Negative Blast — Sonic Ballroom — 15.4 €
#    Status:
#    Raw:
#
#
# Origin: 08.10. K’s Choice 52,95 €
# 2025-10-08 — K’s Choice — Stollwerck — 52.95 €
#    Status:
#    Raw:
#
#
# Origin: 09.10. Hellsongs 25,90 €
# 2025-10-09 — Hellsongs — Helios 37 — 25.9 €
#    Status:
#    Raw:
#
#
# Origin: 09.10. Karaoke Till Death *16,50 €
# 2025-10-09 — Karaoke Till Death — Sonic Ballroom — 16.5 €
#    Status:
#    Raw:
#
#
# Origin: 09.10. Sick Fizz 17,88 €
# 2025-10-09 — Sick Fizz — Stereo Wonderland — 17.88 €
#    Status:
#    Raw:
#
#
# Origin: 10.10. Power Plush 28 €
# 2025-10-10 — Power Plush — Artheater — 28.0 €
#    Status:
#    Raw:
#
#
# Origin: 10.10. Starsailor 34,70 € Ausverkauft!
# 2025-10-10 — Starsailor — Gebäude 9 — 34.7 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 10.10. Karaoke Till Death *16,50 € Ausverkauft!
# 2025-10-10 — Karaoke Till Death — Sonic Ballroom — 16.5 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 10.10. Refused 49,45 € Ausverkauft!
# 2025-10-10 — Refused — Stollwerck — 49.45 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 11.10. Nasty 37 €
# 2025-10-11 — Nasty — Essigfabrik — 37.0 €
#    Status:
#    Raw:
#
#
# Origin: 11.10. Inspector Cluzo 30,45 €
# 2025-10-11 — Inspector Cluzo — Gebäude 9 — 30.45 €
#    Status:
#    Raw:
#
#
# Origin: 11.10. Tim Vantol 35,70 €
# 2025-10-11 — Tim Vantol — Helios 37 — 35.7 €
#    Status:
#    Raw:
#
#
# Origin: 11.10. Prinz Pi 52,79 €
# 2025-10-11 — Prinz Pi — Live Music Hall — 52.79 €
#    Status:
#    Raw:
#
#
# Origin: 11.10. Coheed And Cambria 44,50 € Ausverkauft!
# 2025-10-11 — Coheed And Cambria — Stollwerck — 44.5 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 11.10. Kings Elliot 33,30 €
# 2025-10-11 — Kings Elliot — Yuca — 33.3 €
#    Status:
#    Raw:
#
#
# Origin: 12.10. Sports Team 28,15 €
# 2025-10-12 — Sports Team — Artheater — 28.15 €
#    Status:
#    Raw:
#
#
# Origin: 12.10. Igorrr 44,50 €
# 2025-10-12 — Igorrr — Live Music Hall — 44.5 €
#    Status:
#    Raw:
#
#
# Origin: 14.10. Durand Bernarr 29,30 €
# 2025-10-14 — Durand Bernarr — Club Bahnhof Ehrenfeld — 29.3 €
#    Status:
#    Raw:
#
#
# Origin: 14.10. Black Country, New Road *35,20 € (Popanz Show)
# 2025-10-14 — Black Country, New Road — Gloria — 35.2 €
#    Status:
#    Raw:
#
#
# Origin: 15.10. Snake Eyes @ Stereo Wonderland 18 € (Hardtickets)
# 2025-10-15 — Snake Eyes — Stereo Wonderland — 18.0 €
#    Status:
#    Raw:
#
#
# Origin: 15.10. Beach Bunny @ Gloria 33,50 € (Hardtickets)
# 2025-10-15 — Beach Bunny — Gloria — 33.5 €
#    Status:
#    Raw:
#
#
# Origin: 15.10. False Lefty *19,80 € (Popanz Show)
# 2025-10-15 — False Lefty — Bumann & Sohn — 19.8 €
#    Status:
#    Raw:
#
#
# Origin: 15.10. Chris James 29,30 €
# 2025-10-15 — Chris James — Club Bahnhof Ehrenfeld — 29.3 €
#    Status:
#    Raw:
#
#
# Origin: 15.10. The Obsessed 29,20 €
# 2025-10-15 — The Obsessed — Club Volta — 29.2 €
#    Status:
#    Raw:
#
#
# Origin: 15.10. bac 30 €
# 2025-10-15 — bac — Gebäude 9 — 30.0 €
#    Status:
#    Raw:
#
#
# Origin: 15.10. Beach Bunny 33,50 € (Hardtickets)
# 2025-10-15 — Beach Bunny — Gloria — 33.5 €
#    Status:
#    Raw:
#
#
# Origin: 15.10. Ende 23,70 €
# 2025-10-15 — Ende — Jaki — 23.7 €
#    Status:
#    Raw:
#
#
# Origin: 15.10. Betterov 44,50 € Ausverkauft!
# 2025-10-15 — Betterov — Kulturkirche — 44.5 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 15.10. Jesper Munk 31,40 €
# 2025-10-15 — Jesper Munk — Stadtgarten — 31.4 €
#    Status:
#    Raw:
#
#
# Origin: 15.10. Snake Eyes 18 € (Hardtickets)
# 2025-10-15 — Snake Eyes — Stereo Wonderland — 18.0 €
#    Status:
#    Raw:
#
#
# Origin: 16.10. L.A. Salami *27,50 € (Popanz Show)
# 2025-10-16 — L.A. Salami — Gebäude 9 — 27.5 €
#    Status:
#    Raw:
#
#
# Origin: 16.10. Catapults 23,70 €
# 2025-10-16 — Catapults — Helios 37 — 23.7 €
#    Status:
#    Raw:
#
#
# Origin: 16.10. The Pharcyde 55,10 €
# 2025-10-16 — The Pharcyde — Kantine — 55.1 €
#    Status:
#    Raw:
#
#
# Origin: 17.10. As December Falls 30,70 €
# 2025-10-17 — As December Falls — Gebäude 9 — 30.7 €
#    Status:
#    Raw:
#
#
# Origin: 17.10. Soap & Skin ab 49,45 €
# 2025-10-17 — Soap & Skin — Tanzbrunnen — 49.45 €
#    Status:
#    Raw:
#
#
# Origin: 18.10. ClickClickDecker @ Artheater 27 € (Hardtickets)
# 2025-10-18 — ClickClickDecker — Artheater — 27.0 €
#    Status:
#    Raw:
#
#
# Origin: 18.10. ClickClickDecker 27 € (Hardtickets)
# 2025-10-18 — ClickClickDecker — Artheater — 27.0 €
#    Status:
#    Raw:
#
#
# Origin: 18.10. Jaill 39,40 €
# 2025-10-18 — Jaill — Essigfabrik — 39.4 €
#    Status:
#    Raw:
#
#
# Origin: 18.10. Orannsi Pazuzu 30,37 €
# 2025-10-18 — Orannsi Pazuzu — Gebäude 9 — 30.37 €
#    Status:
#    Raw:
#
#
# Origin: 18.10. Atreyu 46,95 €
# 2025-10-18 — Atreyu — Live Music Hall — 46.95 €
#    Status:
#    Raw:
#
#
# Origin: 18.10. The Backyard Band *15,40 €
# 2025-10-18 — The Backyard Band — Sonic Ballroom — 15.4 €
#    Status:
#    Raw:
#
#
# Origin: 19.10. Caamp 44,35 €
# 2025-10-19 — Caamp — Carlswerk Victoria — 44.35 €
#    Status:
#    Raw:
#
#
# Origin: 20.10. Joya Marleen 26 €
# 2025-10-20 — Joya Marleen — Gebäude 9 — 26.0 €
#    Status:
#    Raw:
#
#
# Origin: 20.10. Banks 47 €
# 2025-10-20 — Banks — Live Music Hall — 47.0 €
#    Status:
#    Raw:
#
#
# Origin: 21.10. Ethel Cain 44,50 € Ausverkauft!
# 2025-10-21 — Ethel Cain — Carlswerk Victoria — 44.5 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 21.10. Castle Rat 29,20 €
# 2025-10-21 — Castle Rat — Club Volta — 29.2 €
#    Status:
#    Raw:
#
#
# Origin: 22.10. Lawn Chair *19,80 € (Popanz Show)
# 2025-10-22 — Lawn Chair — Bumann & Sohn — 19.8 €
#    Status:
#    Raw:
#
#
# Origin: 22.10. Loyle Carner 68,25 €
# 2025-10-22 — Loyle Carner — Palladium — 68.25 €
#    Status:
#    Raw:
#
#
# Origin: 22.10. Fortuna Ehrenfeld ab 28,50 €
# 2025-10-22 — Fortuna Ehrenfeld — Philharmonie — 28.5 €
#    Status:
#    Raw:
#
#
# Origin: 23.10. Grillmaster Flash @ Stereo Wonderland 20 € (Hardtickets)
# 2025-10-23 — Grillmaster Flash — Stereo Wonderland — 20.0 €
#    Status:
#    Raw:
#
#
# Origin: 23.10. Herrenmagazin 27,70 € Ausverkauft!
# 2025-10-23 — Herrenmagazin — Gebäude 9 — 27.7 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 23.10. Paradise Lost 49,25 €
# 2025-10-23 — Paradise Lost — Live Music Hall — 49.25 €
#    Status:
#    Raw:
#
#
# Origin: 23.10. Fortuna Ehrenfeld ab 28,50 € Ausverkauft!
# 2025-10-23 — Fortuna Ehrenfeld — Philharmonie — 28.5 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 23.10. Grillmaster Flash 20 € (Hardtickets)
# 2025-10-23 — Grillmaster Flash — Stereo Wonderland — 20.0 €
#    Status:
#    Raw:
#
#
# Origin: 24.10. Drei Meter Feldweg 30,20 €
# 2025-10-24 — Drei Meter Feldweg — Gebäude 9 — 30.2 €
#    Status:
#    Raw:
#
#
# Origin: 24.10. Afar *22 € (Popanz Show)
# 2025-10-24 — Afar — Jaki — 22.0 €
#    Status:
#    Raw:
#
#
# Origin: 24.10. Mantar 34,70 €
# 2025-10-24 — Mantar — Stollwerck — 34.7 €
#    Status:
#    Raw:
#
#
# Origin: 25.10. Loki 25,90 €
# 2025-10-25 — Loki — Artheater — 25.9 €
#    Status:
#    Raw:
#
#
# Origin: 25.10. ZSK 58,53 €
# 2025-10-25 — ZSK — Carlswerk Victoria — 58.53 €
#    Status:
#    Raw:
#
#
# Origin: 25.10. Leftovers *28,60 € (Popanz Show) Ausverkauft!
# 2025-10-25 — Leftovers — Club Volta — 28.6 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 25.10. Augn 28,10 €
# 2025-10-25 — Augn — Gebäude 9 — 28.1 €
#    Status:
#    Raw:
#
#
# Origin: 25.10. OG Keemo 44,49 € Ausverkauft!
# 2025-10-25 — OG Keemo — Palladium — 44.49 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 26.10. Monophonics 29,20 €
# 2025-10-26 — Monophonics — Club Bahnhof Ehrenfeld — 29.2 €
#    Status:
#    Raw:
#
#
# Origin: 26.10. Larkin Poe 55,75 €
# 2025-10-26 — Larkin Poe — E-Werk — 55.75 €
#    Status:
#    Raw:
#
#
# Origin: 26.10. The Vices 27,60 €
# 2025-10-26 — The Vices — Helios 37 — 27.6 €
#    Status:
#    Raw:
#
#
# Origin: 26.10. Jonny Maar 45,05 €
# 2025-10-26 — Jonny Maar — Live Music Hall — 45.05 €
#    Status:
#    Raw:
#
#
# Origin: 27.10. Low Island 29,20 €
# 2025-10-27 — Low Island — Blue Shell — 29.2 €
#    Status:
#    Raw:
#
#
# Origin: 28.10. Anda Morts 30,30 €
# 2025-10-28 — Anda Morts — Kantine — 30.3 €
#    Status:
#    Raw:
#
#
# Origin: 28.10. Kadavar 44,50 €
# 2025-10-28 — Kadavar — Live Music Hall — 44.5 €
#    Status:
#    Raw:
#
#
# Origin: 28.10. Big Special 32,60 € Ausverkauft!
# 2025-10-28 — Big Special — MTC — 32.6 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 29.10. Bonaparte 47,25 €
# 2025-10-29 — Bonaparte — Kantine — 47.25 €
#    Status:
#    Raw:
#
#
# Origin: 29.10. The Quakes *17,60 €
# 2025-10-29 — The Quakes — Sonic Ballroom — 17.6 €
#    Status:
#    Raw:
#
#
# Origin: 29.10. Nickless 29,10 €
# 2025-10-29 — Nickless — Subway — 29.1 €
#    Status:
#    Raw:
#
#
# Origin: 30.10. The Kiffness 43,50 €
# 2025-10-30 — The Kiffness — Carlswerk Victoria — 43.5 €
#    Status:
#    Raw:
#
#
# Origin: 30.10. The Darkness 44,65 €
# 2025-10-30 — The Darkness — Live Music Hall — 44.65 €
#    Status:
#    Raw:
#
#
# Origin: 31.10. Hell Nights 56,15 €
# 2025-10-31 — Hell Nights — Carlswerk Victoria — 56.15 €
#    Status:
#    Raw:
#
#
# Origin: 01.11. Alarmsignal 30,95 €
# 2025-11-01 — Alarmsignal — Gebäude 9 — 30.95 €
#    Status:
#    Raw:
#
#
# Origin: 01.11. Von Wegen Lisbeth 48 €
# 2025-11-01 — Von Wegen Lisbeth — Palladium — 48.0 €
#    Status:
#    Raw:
#
#
# Origin: 01.11. Banana Peel Slippers *16,50 €
# 2025-11-01 — Banana Peel Slippers — Sonic Ballroom — 16.5 €
#    Status:
#    Raw:
#
#
# Origin: 01.11. Grandbrothers 41,60 €
# 2025-11-01 — Grandbrothers — Stadthalle Köln — 41.6 €
#    Status:
#    Raw:
#
#
# Origin: 02.11. Jasmine.4.t 30,45 €
# 2025-11-02 — Jasmine.4.t — Blue Shell — 30.45 €
#    Status:
#    Raw:
#
#
# Origin: 02.11. Hotel Rimini *27,50 € (Popanz Show)
# 2025-11-02 — Hotel Rimini — Gebäude 9 — 27.5 €
#    Status:
#    Raw:
#
#
# Origin: 02.11. Arrested Development 55 €
# 2025-11-02 — Arrested Development — Live Music Hall — 55.0 €
#    Status:
#    Raw:
#
#
# Origin: 02.11. Billie Marten 30,45 €
# 2025-11-02 — Billie Marten — Luxor — 30.45 €
#    Status:
#    Raw:
#
#
# Origin: 02.11. H-Blockx 58,70 €
# 2025-11-02 — H-Blockx — Palladium — 58.7 €
#    Status:
#    Raw:
#
#
# Origin: 03.11. Deep Sea Diver 28,15 €
# 2025-11-03 — Deep Sea Diver — Blue Shell — 28.15 €
#    Status:
#    Raw:
#
#
# Origin: 03.11. U.S. Girls *24,20 € (Popanz Show)
# 2025-11-03 — U.S. Girls — Bumann & Sohn — 24.2 €
#    Status:
#    Raw:
#
#
# Origin: 03.11. Roya 33,90 €
# 2025-11-03 — Roya — Gebäude 9 — 33.9 €
#    Status:
#    Raw:
#
#
# Origin: 03.11. Everything Everything 36,20 €
# 2025-11-03 — Everything Everything — Kantine — 36.2 €
#    Status:
#    Raw:
#
#
# Origin: 03.11. Bob Dylan ab 70 €
# 2025-11-03 — Bob Dylan — Lanxess Arena — 70.0 €
#    Status:
#    Raw:
#
#
# Origin: 03.11. Kae Tempest 49,28 €
# 2025-11-03 — Kae Tempest — Live Music Hall — 49.28 €
#    Status:
#    Raw:
#
#
# Origin: 03.11. Dropkick Murphys 67,90 €
# 2025-11-03 — Dropkick Murphys — Palladium — 67.9 €
#    Status:
#    Raw:
#
#
# Origin: 04.11. DYSE @ Gebäude 9 29,50 € (Hardtickets)
# 2025-11-04 — DYSE — Gebäude — 9.0 €
#    Status:
#    Raw:
#
#
# Origin: 04.11. Mac DeMarco 49,45 € Ausverkauft!
# 2025-11-04 — Mac DeMarco — Carlswerk Victoria — 49.45 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 04.11. Curtis Harding 44,25 €
# 2025-11-04 — Curtis Harding — Essigfabrik — 44.25 €
#    Status:
#    Raw:
#
#
# Origin: 04.11. DYSE 29,50 € (Hardtickets)
# 2025-11-04 — DYSE — Gebäude 9 — 29.5 €
#    Status:
#    Raw:
#
#
# Origin: 04.11. Jadu Heart 37,20 €
# 2025-11-04 — Jadu Heart — Kulturkirche — 37.2 €
#    Status:
#    Raw:
#
#
# Origin: 04.11. Flipturn 30,45 €
# 2025-11-04 — Flipturn — Luxor — 30.45 €
#    Status:
#    Raw:
#
#
# Origin: 04.11. Dropkick Murphys 67,90 €
# 2025-11-04 — Dropkick Murphys — Palladium — 67.9 €
#    Status:
#    Raw:
#
#
# Origin: 05.11. Bachratten *19,80 €(Popanz Show)
# 2025-11-05 — Bachratten — Bumann & Sohn — 19.8 €
#    Status:
#    Raw:
#
#
# Origin: 05.11. Easy Easy 25,90 €
# 2025-11-05 — Easy Easy — Gebäude 9 — 25.9 €
#    Status:
#    Raw:
#
#
# Origin: 05.11. Malevolence 47 €
# 2025-11-05 — Malevolence — Live Music Hall — 47.0 €
#    Status:
#    Raw:
#
#
# Origin: 05.11. Great Grandpa 30,45 €
# 2025-11-05 — Great Grandpa — Yuca — 30.45 €
#    Status:
#    Raw:
#
#
# Origin: 06.11. Poison Ruin @ Club Volta 25 € (Hardtickets)
# 2025-11-06 — Poison Ruin — Club Volta — 25.0 €
#    Status:
#    Raw:
#
#
# Origin: 06.11. Poison Ruin 25 € (Hardtickets)
# 2025-11-06 — Poison Ruin — Club Volta — 25.0 €
#    Status:
#    Raw:
#
#
# Origin: 06.11. Foxwarren 30,45 €
# 2025-11-06 — Foxwarren — Gebäude 9 — 30.45 €
#    Status:
#    Raw:
#
#
# Origin: 06.11. Nina Chuba ab 52,90 € Ausverkauft!
# 2025-11-06 — Nina Chuba — Lanxess Arena — 52.9 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 07.11. The Summer Set 31,60 €
# 2025-11-07 — The Summer Set — Club Volta — 31.6 €
#    Status:
#    Raw:
#
#
# Origin: 07.11. Pogendroblem *24,20 €
# 2025-11-07 — Pogendroblem — Gebäude 9 — 24.2 €
#    Status:
#    Raw:
#
#
# Origin: 07.11. Becky Sikasa *27,50 € (Popanz Show)
# 2025-11-07 — Becky Sikasa — Kulturkirche — 27.5 €
#    Status:
#    Raw:
#
#
# Origin: 07.11. Bazooka Zirkus *14,30 €
# 2025-11-07 — Bazooka Zirkus — Sonic Ballroom — 14.3 €
#    Status:
#    Raw:
#
#
# Origin: 08.11. Erik Cohen @ Gebäude 9 28 € (Hardtickets)
# 2025-11-08 — Erik Cohen — Gebäude — 9.0 €
#    Status:
#    Raw:
#
#
# Origin: 08.11. Jonny Mahoro 29,20 € Ausverkauft!
# 2025-11-08 — Jonny Mahoro — Artheater — 29.2 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 08.11. Shirley Holmes 23,70 €
# 2025-11-08 — Shirley Holmes — Blue Shell — 23.7 €
#    Status:
#    Raw:
#
#
# Origin: 08.11. Stray From The Path 44,40 €
# 2025-11-08 — Stray From The Path — Carlswerk Victoria — 44.4 €
#    Status:
#    Raw:
#
#
# Origin: 08.11. Kochkraft durch KMA 28,35 €
# 2025-11-08 — Kochkraft durch KMA — Club Volta — 28.35 €
#    Status:
#    Raw:
#
#
# Origin: 08.11. Erik Cohen 28 € (Hardtickets)
# 2025-11-08 — Erik Cohen — Gebäude 9 — 28.0 €
#    Status:
#    Raw:
#
#
# Origin: 08.11. John Butler 45 €
# 2025-11-08 — John Butler — Live Music Hall — 45.0 €
#    Status:
#    Raw:
#
#
# Origin: 08.11. Destroyer + The Weather Station 34,70 €
# 2025-11-08 — Destroyer + The Weather Station — Luxor — 34.7 €
#    Status:
#    Raw:
#
#
# Origin: 09.11. Greyscale 30,55 €
# 2025-11-09 — Greyscale — Helios 37 — 30.55 €
#    Status:
#    Raw:
#
#
# Origin: 10.11. Ghostwoman *27,50 € (Popanz Show)
# 2025-11-10 — Ghostwoman — Gebäude 9 — 27.5 €
#    Status:
#    Raw:
#
#
# Origin: 11.11. King Hannah 29,20 €
# 2025-11-11 — King Hannah — Gebäude 9 — 29.2 €
#    Status:
#    Raw:
#
#
# Origin: 11.11. Steiner & Madlaina 44,50 €
# 2025-11-11 — Steiner & Madlaina — Kulturkirche — 44.5 €
#    Status:
#    Raw:
#
#
# Origin: 12.11. Deki Alem *26,40 € (Popanz Show)
# 2025-11-12 — Deki Alem — Artheater — 26.4 €
#    Status:
#    Raw:
#
#
# Origin: 12.11. The Wytches *19,80 € (Popanz Show)
# 2025-11-12 — The Wytches — Bumann & Sohn — 19.8 €
#    Status:
#    Raw:
#
#
# Origin: 12.11. Triggerfinger 32,50 €
# 2025-11-12 — Triggerfinger — MTC — 32.5 €
#    Status:
#    Raw:
#
#
# Origin: 12.11. Neon Dreams 25,90 €
# 2025-11-12 — Neon Dreams — Subway — 25.9 €
#    Status:
#    Raw:
#
#
# Origin: 13.11. Paula Dalla Corte 28,60 €
# 2025-11-13 — Paula Dalla Corte — Artheater — 28.6 €
#    Status:
#    Raw:
#
#
# Origin: 13.11. McLusky *27,50 € (Popanz Show) verlegt vom Gebäude 9
# 2025-11-13 — McLusky — Club Bahnhof Ehrenfeld — 27.5 €
#    Status: verlegt Gebäude 9
#    Raw: verlegt vom Gebäude 9
#
#
# Origin: 13.11. McLusky *27,50 € (Popanz Show) verlegt in den Club Bahnhof Ehrenfeld
# 2025-11-13 — McLusky — Gebäude 9 — 27.5 €
#    Status: verlegt Club Bahnhof Ehrenfeld
#    Raw: verlegt in den Club Bahnhof Ehrenfeld
#
#
# Origin: 13.11. Cara Rose 29,20 €
# 2025-11-13 — Cara Rose — Kulturkirche — 29.2 €
#    Status:
#    Raw:
#
#
# Origin: 13.11. The Turbo A.C.s *16,50 €
# 2025-11-13 — The Turbo A.C.s — Sonic Ballroom — 16.5 €
#    Status:
#    Raw:
#
#
# Origin: 14.11. Jamie Lawson 30,45 €
# 2025-11-14 — Jamie Lawson — Artheater — 30.45 €
#    Status:
#    Raw:
#
#
# Origin: 14.11. Booze & Glory 34,70 €
# 2025-11-14 — Booze & Glory — Club Volta — 34.7 €
#    Status:
#    Raw:
#
#
# Origin: 14.11. Cate Le Bon *29,70 € (Popanz Show)
# 2025-11-14 — Cate Le Bon — Gebäude 9 — 29.7 €
#    Status:
#    Raw:
#
#
# Origin: 14.11. Der Dumme August *14,30 €
# 2025-11-14 — Der Dumme August — Sonic Ballroom — 14.3 €
#    Status:
#    Raw:
#
#
# Origin: 15.11. Balthvs 37,20 €
# 2025-11-15 — Balthvs — Gebäude 9 — 37.2 €
#    Status:
#    Raw:
#
#
# Origin: 16.11. Obongjayar 31,60 €
# 2025-11-16 — Obongjayar — Club Bahnhof Ehrenfeld — 31.6 €
#    Status:
#    Raw:
#
#
# Origin: 16.11. Skindred 44,65 €
# 2025-11-16 — Skindred — E-Werk — 44.65 €
#    Status:
#    Raw:
#
#
# Origin: 17.11. Gorilla Biscuits, Terror, No Pressure @ Kantine 41,50 (Hardtickets)
# 2025-11-17 — Gorilla Biscuits, Terror, No Pressure — Kantine — 41.5 €
#    Status:
#    Raw:
#
#
# Origin: 17.11. The Young Gods 31,80 €
# 2025-11-17 — The Young Gods — Club Volta — 31.8 €
#    Status:
#    Raw:
#
#
# Origin: 17.11. Mono 34,70 €
# 2025-11-17 — Mono — Gebäude 9 — 34.7 €
#    Status:
#    Raw:
#
#
# Origin: 17.11. Gorilla Biscuits, Terror, No Pressure 41,50 € (Hardtickets)
# 2025-11-17 — Gorilla Biscuits, Terror, No Pressure — Kantine — 41.5 €
#    Status:
#    Raw:
#
#
# Origin: 17.11. Wolf Alice 45,25 €
# 2025-11-17 — Wolf Alice — Palladium — 45.25 €
#    Status:
#    Raw:
#
#
# Origin: 18.11. Upchuck 19,80 € (Popanz Show)
# 2025-11-18 — Upchuck — Bumann & Sohn — 19.8 €
#    Status:
#    Raw:
#
#
# Origin: 18.11. Minami Deutsch *26,40 € (Popanz Show)
# 2025-11-18 — Minami Deutsch — Gebäude 9 — 26.4 €
#    Status:
#    Raw:
#
#
# Origin: 18.11. Softcult 25,85 €
# 2025-11-18 — Softcult — Helios 37 — 25.85 €
#    Status:
#    Raw:
#
#
# Origin: 18.11. Blond 47,40 €
# 2025-11-18 — Blond — Palladium — 47.4 €
#    Status:
#    Raw:
#
#
# Origin: 18.11. The Darts *16,50 €
# 2025-11-18 — The Darts — Sonic Ballroom — 16.5 €
#    Status:
#    Raw:
#
#
# Origin: 19.11. The Roystone Club 29,30 €
# 2025-11-19 — The Roystone Club — Blue Shell — 29.3 €
#    Status:
#    Raw:
#
#
# Origin: 19.11. John Maus 29,20 €
# 2025-11-19 — John Maus — Club Bahnhof Ehrenfeld — 29.2 €
#    Status:
#    Raw:
#
#
# Origin: 19.11. Fil Bo Riva 47,25 €
# 2025-11-19 — Fil Bo Riva — Kulturkirche — 47.25 €
#    Status:
#    Raw:
#
#
# Origin: 20.11. Fritz Kalkbrenner 54,40 €
# 2025-11-20 — Fritz Kalkbrenner — Carlswerk Victoria — 54.4 €
#    Status:
#    Raw:
#
#
# Origin: 20.11. Chefket 35,70 €
# 2025-11-20 — Chefket — Club Bahnhof Ehrenfeld — 35.7 €
#    Status:
#    Raw:
#
#
# Origin: 20.11. Van Holzen 29,10 €
# 2025-11-20 — Van Holzen — Gebäude 9 — 29.1 €
#    Status:
#    Raw:
#
#
# Origin: 20.11. Killwitch Engage 59 €
# 2025-11-20 — Killwitch Engage — Palladium — 59.0 €
#    Status:
#    Raw:
#
#
# Origin: 20.11. Sedlmeir *15,40 €
# 2025-11-20 — Sedlmeir — Sonic Ballroom — 15.4 €
#    Status:
#    Raw:
#
#
# Origin: 21.11. Marathonmann 29,80 €
# 2025-11-21 — Marathonmann — Gebäude 9 — 29.8 €
#    Status:
#    Raw:
#
#
# Origin: 21.11. Karoshi *15,40 €
# 2025-11-21 — Karoshi — Sonic Ballroom — 15.4 €
#    Status:
#    Raw:
#
#
# Origin: 22.11. Swim School 28,15 €
# 2025-11-22 — Swim School — Helios 37 — 28.15 €
#    Status:
#    Raw:
#
#
# Origin: 22.11. Sons 27 €
# 2025-11-22 — Sons — MTC — 27.0 €
#    Status:
#    Raw:
#
#
# Origin: 22.11. The Schizophonics *17,60 €
# 2025-11-22 — The Schizophonics — Sonic Ballroom — 17.6 €
#    Status:
#    Raw:
#
#
# Origin: 22.11. Panic Shack 30,30 €
# 2025-11-22 — Panic Shack — Yuca — 30.3 €
#    Status:
#    Raw:
#
#
# Origin: 23.11. Matt Anderson 34,70 €
# 2025-11-23 — Matt Anderson — Gebäude 9 — 34.7 €
#    Status:
#    Raw:
#
#
# Origin: 23.11. Noga Erez 45 €
# 2025-11-23 — Noga Erez — Live Music Hall — 45.0 €
#    Status:
#    Raw:
#
#
# Origin: 24.11. The Subways 40,05 €
# 2025-11-24 — The Subways — Stollwerck — 40.05 €
#    Status:
#    Raw:
#
#
# Origin: 25.11. Mother Tongue 33,60 €
# 2025-11-25 — Mother Tongue — Club Volta — 33.6 €
#    Status:
#    Raw:
#
#
# Origin: 25.11. Frankie And The Witchfingers *25,30 € (Popanz Show)
# 2025-11-25 — Frankie And The Witchfingers — Gebäude 9 — 25.3 €
#    Status:
#    Raw:
#
#
# Origin: 25.11. Pudeldame 28,10 €
# 2025-11-25 — Pudeldame — Helios 37 — 28.1 €
#    Status:
#    Raw:
#
#
# Origin: 25.11. Mine 61,90 €
# 2025-11-25 — Mine — Palladium — 61.9 €
#    Status:
#    Raw:
#
#
# Origin: 26.11. Florence Black 30,60 €
# 2025-11-26 — Florence Black — MTC — 30.6 €
#    Status:
#    Raw:
#
#
# Origin: 26.11. Long Tall Texans *16,50 €
# 2025-11-26 — Long Tall Texans — Sonic Ballroom — 16.5 €
#    Status:
#    Raw:
#
#
# Origin: 26.11. Bertie Newman 25,90 €
# 2025-11-26 — Bertie Newman — Wohngemeinschaft — 25.9 €
#    Status:
#    Raw:
#
#
# Origin: 27.11. Benjrose 32,75 €
# 2025-11-27 — Benjrose — Club Bahnhof Ehrenfeld — 32.75 €
#    Status:
#    Raw:
#
#
# Origin: 27.11. Baxter Dury 44,65 €
# 2025-11-27 — Baxter Dury — Kantine — 44.65 €
#    Status:
#    Raw:
#
#
# Origin: 27.11. The Scratch 30,45 €
# 2025-11-27 — The Scratch — MTC — 30.45 €
#    Status:
#    Raw:
#
#
# Origin: 28.11. Dari 34,90 €
# 2025-11-28 — Dari — Club Bahnhof Ehrenfeld — 34.9 €
#    Status:
#    Raw:
#
#
# Origin: 28.11. Guilt Trip 33,75 €
# 2025-11-28 — Guilt Trip — Essigfabrik — 33.75 €
#    Status:
#    Raw:
#
#
# Origin: 28.11. Sparkling *22 € (Popanz Show)
# 2025-11-28 — Sparkling — Helios 37 — 22.0 €
#    Status:
#    Raw:
#
#
# Origin: 28.11. Jerub 33,90 €
# 2025-11-28 — Jerub — Yuca — 33.9 €
#    Status:
#    Raw:
#
#
# Origin: 29.11. Joy Crookes 41,80 €
# 2025-11-29 — Joy Crookes — Live Music Hall — 41.8 €
#    Status:
#    Raw:
#
#
# Origin: 29.11. Skinny Lister 32,75 €
# 2025-11-29 — Skinny Lister — Luxor — 32.75 €
#    Status:
#    Raw:
#
#
# Origin: 30.11. Chelsea Grin 43,35 €
# 2025-11-30 — Chelsea Grin — Essigfabrik — 43.35 €
#    Status:
#    Raw:
#
#
# Origin: 30.11. Slow Crush 30,70 €
# 2025-11-30 — Slow Crush — Helios 37 — 30.7 €
#    Status:
#    Raw:
#
#
# Origin: 01.12. Julian Knoth *19,80 € (Popanz Show)
# 2025-12-01 — Julian Knoth — Bumann & Sohn — 19.8 €
#    Status:
#    Raw:
#
#
# Origin: 01.12. Friso 33,70 €
# 2025-12-01 — Friso — Gebäude 9 — 33.7 €
#    Status:
#    Raw:
#
#
# Origin: 01.12. Die Höchste Eisenbahn 42,20 € Ausverkauft!
# 2025-12-01 — Die Höchste Eisenbahn — Gloria — 42.2 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 01.12. The Hives 57,55 €
# 2025-12-01 — The Hives — Palladium — 57.55 €
#    Status:
#    Raw:
#
#
# Origin: 02.12. Deviloof 47,65 €
# 2025-12-02 — Deviloof — MTC — 47.65 €
#    Status:
#    Raw:
#
#
# Origin: 02.12. Big Sleep 28,15 €
# 2025-12-02 — Big Sleep — Yuca — 28.15 €
#    Status:
#    Raw:
#
#
# Origin: 03.12. Yuuf *18,70 € (Popanz Show)
# 2025-12-03 — Yuuf — Bumann & Sohn — 18.7 €
#    Status:
#    Raw:
#
#
# Origin: 05.12. Of Mice And Men 42,40 €
# 2025-12-05 — Of Mice And Men — Essigfabrik — 42.4 €
#    Status:
#    Raw:
#
#
# Origin: 05.12. Nichts *16,50 €
# 2025-12-05 — Nichts — Sonic Ballroom — 16.5 €
#    Status:
#    Raw:
#
#
# Origin: 07.12. Lambrini Girls (Popanz Show) Verlegt in die Kantine
# 2025-12-07 — Lambrini Girls — Gebäude 9 — nan €
#    Status: verlegt Kantine
#    Raw: Verlegt in die Kantine
#
#
# Origin: 07.12. Ethan Regan 28,15 €
# 2025-12-07 — Ethan Regan — Jaki — 28.15 €
#    Status:
#    Raw:
#
#
# Origin: 07.12. Lambrini Girls *27,50 € (Popanz Show)  verlegt vom Gebäude 9
# 2025-12-07 — Lambrini Girls — Kantine — 27.5 €
#    Status: verlegt Gebäude 9
#    Raw: verlegt vom Gebäude 9
#
#
# Origin: 08.12. David Bay 23,70 €
# 2025-12-08 — David Bay — Jaki — 23.7 €
#    Status:
#    Raw:
#
#
# Origin: 08.12. Royal Otis 47 €
# 2025-12-08 — Royal Otis — Palladium — 47.0 €
#    Status:
#    Raw:
#
#
# Origin: 09.12. Rise Of The Northstar 44,50 €
# 2025-12-09 — Rise Of The Northstar — Club Volta — 44.5 €
#    Status:
#    Raw:
#
#
# Origin: 09.12. The Meteors 31,95 €
# 2025-12-09 — The Meteors — Gebäude 9 — 31.95 €
#    Status:
#    Raw:
#
#
# Origin: 09.12. Fortuna Ehrenfeld 44,63 €
# 2025-12-09 — Fortuna Ehrenfeld — Kulturkirche — 44.63 €
#    Status:
#    Raw:
#
#
# Origin: 10.12. The Pill 24,70 €
# 2025-12-10 — The Pill — Blue Shell — 24.7 €
#    Status:
#    Raw:
#
#
# Origin: 10.12. Herrenmagazin 41,05 €
# 2025-12-10 — Herrenmagazin — Gloria — 41.05 €
#    Status:
#    Raw:
#
#
# Origin: 10.12. Fortuna Ehrenfeld 44,63 €
# 2025-12-10 — Fortuna Ehrenfeld — Kulturkirche — 44.63 €
#    Status:
#    Raw:
#
#
# Origin: 10.12. Clutch 43,50 €
# 2025-12-10 — Clutch — Live Music Hall — 43.5 €
#    Status:
#    Raw:
#
#
# Origin: 10.12. The Rural Alberta Advantage 35 €
# 2025-12-10 — The Rural Alberta Advantage — Stadtgarten — 35.0 €
#    Status:
#    Raw:
#
#
# Origin: 11.12. Danko Jones 40,05 €
# 2025-12-11 — Danko Jones — Carlswerk Victoria — 40.05 €
#    Status:
#    Raw:
#
#
# Origin: 11.12. Iedereen *24,20 € (Popanz Show)
# 2025-12-11 — Iedereen — Gebäude 9 — 24.2 €
#    Status:
#    Raw:
#
#
# Origin: 12.12. Extrabreit 44,85 €
# 2025-12-12 — Extrabreit — Gebäude 9 — 44.85 €
#    Status:
#    Raw:
#
#
# Origin: 13.12. KMPFSPRT 24,20 € € (Hardtickets)
# 2025-12-13 — KMPFSPRT — Gebäude 9 — 24.2 €
#    Status:
#    Raw:
#
#
# Origin: 14.12. Loathe 37,30 €
# 2025-12-14 — Loathe — Gebäude 9 — 37.3 €
#    Status:
#    Raw:
#
#
# Origin: 17.12. Dota 41,20 €
# 2025-12-17 — Dota — Carlswerk Victoria — 41.2 €
#    Status:
#    Raw:
#
#
# Origin: 19.12. Oxo 86 38,55 €
# 2025-12-19 — Oxo — Essigfabrik — 86.0 €
#    Status:
#    Raw:
#
#
# Origin: 19.12. Landmvrks 56,45 €
# 2025-12-19 — Landmvrks — Palladium — 56.45 €
#    Status:
#    Raw:
#
#
# Origin: 22.12. Erdmöbel 35,10 €
# 2025-12-22 — Erdmöbel — Gloria — 35.1 €
#    Status:
#    Raw:
#
#
# Origin: 27.12. Bernd Begemann *22 €
# 2025-12-27 — Bernd Begemann — Gebäude 9 — 22.0 €
#    Status:
#    Raw:
#
#
# Origin: 30.12. Erobique 42,20 €
# 2025-12-30 — Erobique — Stadthalle Köln — 42.2 €
#    Status:
#    Raw:
#
#
# Origin: 09.01. Born Of Osiris 42,95 €
# 2026-01-09 — Born Of Osiris — Gebäude 9 — 42.95 €
#    Status:
#    Raw:
#
#
# Origin: 10.01. Demented Are Go 32,95 €
# 2026-01-10 — Demented Are Go — Gebäude 9 — 32.95 €
#    Status:
#    Raw:
#
#
# Origin: 16.01. HGich.T 34,70 €
# 2026-01-16 — HGich.T — Essigfabrik — 34.7 €
#    Status:
#    Raw:
#
#
# Origin: 18.01. Saturdays at your place @ Helios 37 25 €  (Hardtickets)
# 2026-01-18 — Saturdays at your place — Helios — 37.0 €
#    Status:
#    Raw:
#
#
# Origin: 18.01. Saturdays at your place 25 € (Hardtickets)
# 2026-01-18 — Saturdays at your place — Helios 37 — 25.0 €
#    Status:
#    Raw:
#
#
# Origin: 23.01. Lionheart 49,49 €
# 2026-01-23 — Lionheart — Carlswerk Victoria — 49.49 €
#    Status:
#    Raw:
#
#
# Origin: 23.01. Pabst *27,50 €
# 2026-01-23 — Pabst — Gebäude 9 — 27.5 €
#    Status:
#    Raw:
#
#
# Origin: 23.01. Slime 44,90 €
# 2026-01-23 — Slime — Kantine — 44.9 €
#    Status:
#    Raw:
#
#
# Origin: 23.01. Deaf Havana 30,45 € Ausverkauft!
# 2026-01-23 — Deaf Havana — Luxor — 30.45 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 23.01. Jinjer 51,25 €
# 2026-01-23 — Jinjer — Palladium — 51.25 €
#    Status:
#    Raw:
#
#
# Origin: 24.01. Still Talk 25,90 €
# 2026-01-24 — Still Talk — Helios 37 — 25.9 €
#    Status:
#    Raw:
#
#
# Origin: 27.01. Tortoise 42,40 €
# 2026-01-27 — Tortoise — Kantine — 42.4 €
#    Status:
#    Raw:
#
#
# Origin: 29.01. Deaf Havana 31,60 €
# 2026-01-29 — Deaf Havana — Club Volta — 31.6 €
#    Status:
#    Raw:
#
#
# Origin: 29.01. Nanowar Of Steel 40,70 €
# 2026-01-29 — Nanowar Of Steel — Gebäude 9 — 40.7 €
#    Status:
#    Raw:
#
#
# Origin: 30.01. Militarie Gun 30,45 €
# 2026-01-30 — Militarie Gun — MTC — 30.45 €
#    Status:
#    Raw:
#
#
# Origin: 31.01. Kontrollverlust 32,40 €
# 2026-01-31 — Kontrollverlust — Gebäude 9 — 32.4 €
#    Status:
#    Raw:
#
#
# Origin: 03.02. The Hidden Cameras 29,20 €
# 2026-02-03 — The Hidden Cameras — Bumann & Sohn — 29.2 €
#    Status:
#    Raw:
#
#
# Origin: 04.02. Anna Von Hausswolff 32,75 €
# 2026-02-04 — Anna Von Hausswolff — Gebäude 9 — 32.75 €
#    Status:
#    Raw:
#
#
# Origin: 05.02. Counterparts 44,40 €
# 2026-02-05 — Counterparts — Live Music Hall — 44.4 €
#    Status:
#    Raw:
#
#
# Origin: 08.02. Syml 40,05 €
# 2026-02-08 — Syml — Carlswerk Victoria — 40.05 €
#    Status:
#    Raw:
#
#
# Origin: 08.02. Earl Sweatshirt 46,40 €
# 2026-02-08 — Earl Sweatshirt — Essigfabrik — 46.4 €
#    Status:
#    Raw:
#
#
# Origin: 10.02. Cory Hanson *22 € (Popanz Show)
# 2026-02-10 — Cory Hanson — Bumann & Sohn — 22.0 €
#    Status:
#    Raw:
#
#
# Origin: 10.02. Blossoms 33,90 €
# 2026-02-10 — Blossoms — Kantine — 33.9 €
#    Status:
#    Raw:
#
#
# Origin: 10.02. Noso 24,70 €
# 2026-02-10 — Noso — Yuca — 24.7 €
#    Status:
#    Raw:
#
#
# Origin: 11.02. Schramm 25,90 €
# 2026-02-11 — Schramm — Bumann & Sohn — 25.9 €
#    Status:
#    Raw:
#
#
# Origin: 11.02. The Aces 31,60 €
# 2026-02-11 — The Aces — MTC — 31.6 €
#    Status:
#    Raw:
#
#
# Origin: 19.02. They Are Gutting A Body Of Water *22 € (Popanz Show)
# 2026-02-19 — They Are Gutting A Body Of Water — Bumann & Sohn — 22.0 €
#    Status:
#    Raw:
#
#
# Origin: 20.02. Arms Lenght 33,35 €
# 2026-02-20 — Arms Lenght — Gebäude 9 — 33.35 €
#    Status:
#    Raw:
#
#
# Origin: 21.02. Elwood Stray & Our Mirage 28,95 €
# 2026-02-21 — Elwood Stray & Our Mirage — Gebäude 9 — 28.95 €
#    Status:
#    Raw:
#
#
# Origin: 21.02. Tulpe 29,40 €
# 2026-02-21 — Tulpe — MTC — 29.4 €
#    Status:
#    Raw:
#
#
# Origin: 22.02. Rosmarin 30,70 €
# 2026-02-22 — Rosmarin — Gebäude 9 — 30.7 €
#    Status:
#    Raw:
#
#
# Origin: 24.02. White Lies 46,95 €
# 2026-02-24 — White Lies — Live Music Hall — 46.95 €
#    Status:
#    Raw:
#
#
# Origin: 26.02. A.A. Williams @ Gebäude 9 29 € (Hardtickets)
# 2026-02-26 — A.A. Williams — Gebäude — 9.0 €
#    Status:
#    Raw:
#
#
# Origin: 26.02. A.A. Williams 29 € (Hardtickets)
# 2026-02-26 — A.A. Williams — Gebäude 9 — 29.0 €
#    Status:
#    Raw:
#
#
# Origin: 28.02. Coach Party 27 €
# 2026-02-28 — Coach Party — MTC — 27.0 €
#    Status:
#    Raw:
#
#
# Origin: 28.02. Heaven Shall Burn 69,40 €
# 2026-02-28 — Heaven Shall Burn — Palladium — 69.4 €
#    Status:
#    Raw:
#
#
# Origin: 01.03. Pool Kids 27 €
# 2026-03-01 — Pool Kids — Blue Shell — 27.0 €
#    Status:
#    Raw:
#
#
# Origin: 03.03. Good Neighbours 33,90 €
# 2026-03-03 — Good Neighbours — Gebäude 9 — 33.9 €
#    Status:
#    Raw:
#
#
# Origin: 05.03. Yin Yin 29,80 €
# 2026-03-05 — Yin Yin — Gloria — 29.8 €
#    Status:
#    Raw:
#
#
# Origin: 06.03. Wizo 51,75 €
# 2026-03-06 — Wizo — Carlswerk Victoria — 51.75 €
#    Status:
#    Raw:
#
#
# Origin: 07.03. Of Monsters and Men 53,30 €
# 2026-03-07 — Of Monsters and Men — Carlswerk Victoria — 53.3 €
#    Status:
#    Raw:
#
#
# Origin: 08.03. Maximo Park 49,10 €
# 2026-03-08 — Maximo Park — Carlswerk Victoria — 49.1 €
#    Status:
#    Raw:
#
#
# Origin: 10.03. La Dispute 35,05 €
# 2026-03-10 — La Dispute — Live Music Hall — 35.05 €
#    Status:
#    Raw:
#
#
# Origin: 11.03. Tristan Brusch 32 €
# 2026-03-11 — Tristan Brusch — Club Bahnhof Ehrenfeld — 32.0 €
#    Status:
#    Raw:
#
#
# Origin: 12.03. Schmutzki 38,45 €
# 2026-03-12 — Schmutzki — Club Volta — 38.45 €
#    Status:
#    Raw:
#
#
# Origin: 13.03. Kafvka @ Gebäude 9 (CTS)
# 2026-03-13 — Kafvka — Gebäude — 9.0 €
#    Status:
#    Raw:
#
#
# Origin: 13.03. Romano 40,65 €
# 2026-03-13 — Romano — Artheater — 40.65 €
#    Status:
#    Raw:
#
#
# Origin: 13.03. Kafvka 31,30 €
# 2026-03-13 — Kafvka — Gebäude 9 — 31.3 €
#    Status:
#    Raw:
#
#
# Origin: 14.03. Sprints 33,90 €
# 2026-03-14 — Sprints — Kantine — 33.9 €
#    Status:
#    Raw:
#
#
# Origin: 15.03. Divine Comedy 53,90 € Ausverkauft!
# 2026-03-15 — Divine Comedy — Stadthalle Köln — 53.9 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 17.03. Spidergawd 41,50 €
# 2026-03-17 — Spidergawd — Gebäude 9 — 41.5 €
#    Status:
#    Raw:
#
#
# Origin: 17.03. Belle & Sebastian performing Tigermilk 55 €
# 2026-03-17 — Belle & Sebastian performing Tigermilk — Stadthalle Köln — 55.0 €
#    Status:
#    Raw:
#
#
# Origin: 18.03. Betterov 44,50 €
# 2026-03-18 — Betterov — Carlswerk Victoria — 44.5 €
#    Status:
#    Raw:
#
#
# Origin: 18.03. Kapa Tult *27,50 €
# 2026-03-18 — Kapa Tult — Gebäude 9 — 27.5 €
#    Status:
#    Raw:
#
#
# Origin: 18.03. Geese 30,45 €
# 2026-03-18 — Geese — Kantine — 30.45 €
#    Status:
#    Raw:
#
#
# Origin: 18.03. Belle & Sebastian performing If You’re Feeling Sinister 55 €
# 2026-03-18 — Belle & Sebastian performing If You’re Feeling Sinister — Stadthalle Köln — 55.0 €
#    Status:
#    Raw:
#
#
# Origin: 19.03. Fatoni 45,25 €
# 2026-03-19 — Fatoni — Carlswerk Victoria — 45.25 €
#    Status:
#    Raw:
#
#
# Origin: 20.03. Kanonenfieber 44,70 € Ausverkauft!
# 2026-03-20 — Kanonenfieber — Carlswerk Victoria — 44.7 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 20.03. Godspeed You! Black Emperor 41,87 €
# 2026-03-20 — Godspeed You! Black Emperor — Kantine — 41.87 €
#    Status:
#    Raw:
#
#
# Origin: 24.03. Deus 51 €
# 2026-03-24 — Deus — Stollwerck — 51.0 €
#    Status:
#    Raw:
#
#
# Origin: 26.03. Kapelle Petra 39,90 €
# 2026-03-26 — Kapelle Petra — Carlswerk Victoria — 39.9 €
#    Status:
#    Raw:
#
#
# Origin: 27.03. Doctor Krapula *26,40 €
# 2026-03-27 — Doctor Krapula — Gebäude 9 — 26.4 €
#    Status:
#    Raw:
#
#
# Origin: 29.03. The Magic Mumble Jumble 35,90 €
# 2026-03-29 — The Magic Mumble Jumble — Club Bahnhof Ehrenfeld — 35.9 €
#    Status:
#    Raw:
#
#
# Origin: 01.04. Black Sea Dahu 41,85 €
# 2026-04-01 — Black Sea Dahu — Gloria — 41.85 €
#    Status:
#    Raw:
#
#
# Origin: 02.04. Milliarden 39,90 €
# 2026-04-02 — Milliarden — Gloria — 39.9 €
#    Status:
#    Raw:
#
#
# Origin: 04.04. Full Of Hell, The Body 33,77 €
# 2026-04-04 — Full Of Hell, The Body — Gebäude 9 — 33.77 €
#    Status:
#    Raw:
#
#
# Origin: 04.04. Franz Ferdinand 62,50 €
# 2026-04-04 — Franz Ferdinand — Palladium — 62.5 €
#    Status:
#    Raw:
#
#
# Origin: 11.04. The Haunted Youth *25,30 € (Popanz Show) Ausverkauft!
# 2026-04-11 — The Haunted Youth — Artheater — 25.3 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 12.04. Kaffkiez 54,40 €
# 2026-04-12 — Kaffkiez — Palladium — 54.4 €
#    Status:
#    Raw:
#
#
# Origin: 13.04. Henge 29,20 €
# 2026-04-13 — Henge — Club Bahnhof Ehrenfeld — 29.2 €
#    Status:
#    Raw:
#
#
# Origin: 14.04. Big Thief 54,24 €
# 2026-04-14 — Big Thief — E-Werk — 54.24 €
#    Status:
#    Raw:
#
#
# Origin: 15.04. Keshavara *22 € (Popanz Show)
# 2026-04-15 — Keshavara — Bumann & Sohn — 22.0 €
#    Status:
#    Raw:
#
#
# Origin: 16.04. Mobb Deep 44 €
# 2026-04-16 — Mobb Deep — Essigfabrik — 44.0 €
#    Status:
#    Raw:
#
#
# Origin: 16.04. Lansdowne 29,10 €
# 2026-04-16 — Lansdowne — Gebäude 9 — 29.1 €
#    Status:
#    Raw:
#
#
# Origin: 17.04. The Toten Crackhuren im Kofferraum 33,50 €
# 2026-04-17 — The Toten Crackhuren im Kofferraum — Gebäude 9 — 33.5 €
#    Status:
#    Raw:
#
#
# Origin: 20.04. Eläkeläiset 30,30 €
# 2026-04-20 — Eläkeläiset — Helios 37 — 30.3 €
#    Status:
#    Raw:
#
#
# Origin: 21.04. Hundreds 42,75 €
# 2026-04-21 — Hundreds — Gebäude 9 — 42.75 €
#    Status:
#    Raw:
#
#
# Origin: 07.05. Salò 33,80 €
# 2026-05-07 — Salò — Gebäude 9 — 33.8 €
#    Status:
#    Raw:
#
#
# Origin: 08.05. Hardline 41,50 €
# 2026-05-08 — Hardline — Gebäude 9 — 41.5 €
#    Status:
#    Raw:
#
#
# Origin: 08.05. She Past Away 40,77 €
# 2026-05-08 — She Past Away — Kantine — 40.77 €
#    Status:
#    Raw:
#
#
# Origin: 10.05. RedHook 25,80 €
# 2026-05-10 — RedHook — Tsunami Club — 25.8 €
#    Status:
#    Raw:
#
#
# Origin: 11.05. Sportfreunde Stiller 53,85 €
# 2026-05-11 — Sportfreunde Stiller — Palladium — 53.85 €
#    Status:
#    Raw:
#
#
# Origin: 30.05. Rami Hattab 34,70 €
# 2026-05-30 — Rami Hattab — Gebäude 9 — 34.7 €
#    Status:
#    Raw:
#
#
# Origin: 19.06. Audio88 & Yassin 43,75 €
# 2026-06-19 — Audio88 & Yassin — Carlswerk Victoria — 43.75 €
#    Status:
#    Raw:
#
#
# Origin: 12.09. Toxoplasma *16,50 € Ausverkauft!
# 2026-09-12 — Toxoplasma — Sonic Ballroom — 16.5 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 13.09. Moneybrother 38,20 € Ausverkauft!
# 2026-09-13 — Moneybrother — Gebäude 9 — 38.2 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 13.09. Gogol Bordello 46,95 €
# 2026-09-13 — Gogol Bordello — Live Music Hall — 46.95 €
#    Status:
#    Raw:
#
#
# Origin: 13.09. The Slapstickers *17,60 €
# 2026-09-13 — The Slapstickers — Sonic Ballroom — 17.6 €
#    Status:
#    Raw:
#
#
# Origin: 14.09. Greg Freeman 29,30 €
# 2026-09-14 — Greg Freeman — Blue Shell — 29.3 €
#    Status:
#    Raw:
#
#
# Origin: 14.09. Richy Mitch & The Coal Miners 32,75 €
# 2026-09-14 — Richy Mitch & The Coal Miners — Gebäude 9 — 32.75 €
#    Status:
#    Raw:
#
#
# Origin: 15.09. Lord Huron 43,50 € Ausverkauft!
# 2026-09-15 — Lord Huron — E-Werk — 43.5 €
#    Status: ausverkauft
#    Raw: Ausverkauft!
#
#
# Origin: 15.09. Dope Lemon 47,80 €
# 2026-09-15 — Dope Lemon — Kantine — 47.8 €
#    Status:
#    Raw:
#
#
# Origin: 15.09. Chloe Moriondo 30,45 €
# 2026-09-15 — Chloe Moriondo — Yuca — 30.45 €
#    Status:
#    Raw:
#
#
# Origin: 16.09. Lord Rochester *16,50 €
# 2026-09-16 — Lord Rochester — Sonic Ballroom — 16.5 €
#    Status:
#    Raw:
#
#
# Origin: 17.09. Man/Woman/Chainsaw *19,80 € (Popanz Show)
# 2026-09-17 — Man/Woman/Chainsaw — Bumann & Sohn — 19.8 €
#    Status:
#    Raw:
#
#
# Origin: 17.09. Teenage Dads 28,15 €
# 2026-09-17 — Teenage Dads — MTC — 28.15 €
#    Status:
#    Raw:
#
#
# Origin: 18.09. Loving *19,80 € (Popanz Show)
# 2026-09-18 — Loving — Bumann & Sohn — 19.8 €
#    Status:
#    Raw:
#
#
# Origin: 18.09. Ten56. 31,60 €
# 2026-09-18 — Ten56. — Gebäude 9 — 31.6 €
#    Status:
#    Raw:

# %%
from IPython.display import HTML

print(f"Events: {len(events)}")

def render_events(events):
    html = "<ul style='list-style:none; padding:0;'>"
    for e in events:
        weekday = e['date'].strftime("%a")
        html += f"""
        <li style="margin:10px 0; padding:10px; border:1px solid #ddd; border-radius:8px;">
            <b>{weekday}. {e['date'].date()} — {e['band']} — {e['location']} — {e['price_eur']} €</b><br>
            <i>Genres:</i> {', '.join(e['genres']) if isinstance(e['genres'], (list, tuple)) else e['genres']}<br>
            <a href="{e['spotify_link']}" target="_blank" style="color:#1DB954; text-decoration:none;">🎵 Open in Spotify</a>
        </li>
        """
    html += "</ul>"
    return HTML(html)

render_events(events)
# Out:
# Events: 374
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[162], line 19
#      16     html += "</ul>"
#      17     return HTML(html)
# ---> 19 render_events(events)
#
# Cell In[162], line 12, in render_events(events)
#       7 for e in events:
#       8     weekday = e['date'].strftime("%a")
#       9     html += f"""
#      10     <li style="margin:10px 0; padding:10px; border:1px solid #ddd; border-radius:8px;">
#      11         <b>{weekday}. {e['date'].date()} — {e['band']} — {e['location']} — {e['price_eur']} €</b><br>
# ---> 12         <i>Genres:</i> {', '.join(e['genres']) if isinstance(e['genres'], (list, tuple)) else e['genres']}<br>
#      13         <a href="{e['spotify_link']}" target="_blank" style="color:#1DB954; text-decoration:none;">🎵 Open in Spotify</a>
#      14     </li>
#      15     """
#      16 html += "</ul>"
#      17 return HTML(html)
#
# KeyError: 'genres'
